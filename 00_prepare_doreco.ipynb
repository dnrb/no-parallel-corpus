# %% [markdown]
# ## modules, globals, and functions

# %%
doreco_folder = '~/Google Drive/data/doreco_v2/' # replace by location of doreco corpus

import os
import re
import pandas as pd
import numpy as np
import json
from unidecode import unidecode
from collections import Counter, defaultdict

# %%
# this generates a master list

punct = '–"()¡!., ¿?%@#;\t'

def eliminate_asterisks(x):
    return list(filter(lambda x : re.match(r'^([\*#]*|\<p\:\>)$', x) == None or x == '', x))

def filter_wd(x, doc):
    if re.search('[012456789]', x) != None: return ''
    elif '3' in x and doc != 'arap1274': return ''
    if re.search(r'^(\(\(|[-\[]).*([\]-]|\)\))', x) != None : return '' # comments and truncations
    elif ' ' in x.strip(' '): return ''
    x = re.sub(r'(.*)\((.*)\)(.*)', r'\1\2\3', 
                      re.sub(r'[.\-*]', '', re.sub(r'\<.*\>', '', re.sub(r'\<\<.*\>(.+)\>', r'\1', x)).strip(punct)))
    return re.sub(r'<<[a-z]+>(.*)>', r'\1', x)

def mb_gl_align(mb, gl, doc):
    if doc == 'goro1270':
        mb = [m for M in mb for m in re.sub(r'[^\s]=', ' =', M).split(' ')]
        if len(mb) == len(gl): return mb, gl
    pfx, sfx = [], []
    while len(mb) > 0 and len(gl) > 0 and re.search(r'^([=\-A-Z0-9].*|.*[-=])$', gl[0]) != None:
        pfx.append((mb.pop(0),gl.pop(0)))
    while len(mb) > 0 and len(gl) > 0 and re.search(r'^([=\-A-Z0-9].*|.*[-=])$', gl[-1]) != None:
        sfx.append((mb.pop(-1), gl.pop(-1)))
    stem = [('.'.join(mb), '.'.join(gl))]
    mb,gl = zip(*pfx + stem + sfx)
    return mb, gl

# %% [markdown]
# ## morphological list generation

# %% [markdown]
# ### character normalization

# %%
from unidecode import unidecode

bichar_transducer = json.loads(open('combined_character_transduction.json').read())

def train_global_combining_character_transducer():
    combining_char = set(range(768,880))
    char_seen = set()
    combining_digraph_ctr = Counter()
    for f in sorted(filter(lambda f : f.endswith('master.tsv'), os.listdir(outdir))):
        char_f, str_f = set(), set()
        for w,seg,freq in map(lambda x : x.split('\t'), open(outdir + f)):
            char_f |= set(w+seg.lower())
            str_f |= {w.lower(), seg.lower()}
        char_seen |= char_f
        #print(f, len(char_f))
        if next((True for c in char_f if ord(c) in combining_char),False):
            for s in str_f:
                for ci,c in enumerate(s[1:]):
                    if ord(c) in combining_char:
                        combining_digraph_ctr[s[ci:ci+2]] += 1
    transducer = {}
    for c, v in combining_digraph_ctr.most_common():
        if len(c) != 2: print(c,v); continue
        ci,cj = c
        replacement = next((c for c in map(chr, range(0,767))
                             if c.islower() and c not in char_seen and c != unidecode(ci) and unidecode(c) == unidecode(ci)),
                           next((c for c in map(chr, chain(range(161,191))) if c not in char_seen),None))
        char_seen.add(replacement)
        #print('<<<' if replacement == None else '   ', 'from:', c, 'to:', replacement, 'U=%d' % (ord(replacement) if replacement != None else -1), v)
        transducer[c] = replacement
    return transducer
            
def bicharacter_transduction(string, bichar_transducer=bichar_transducer):
    new_string = ''
    string = list(string)
    while string != []:
        c = string.pop(0)
        if len(string) > 0 and c + string[0] in bichar_transducer:
            new_string += bichar_transducer[c+string[0]]
            string.pop(0)
        else:
            new_string += c
    return new_string

BT = bicharacter_transduction

# %%
with open('combined_character_transduction.json', 'w') as fout:
    fout.write(json.dumps(bichar_transducer, ensure_ascii=False))

# %%
PUNCT_WD = '()_…:"—§”.,?!<>[]\':-='
APOSTROPHE_GLOTTAL_LANGUAGES = ['arap1274', 'cabe1245', 'even1259', 'goem1240', 'kama1351', 'sanz1248','movi1243', 'vera1241', 'urum1249',
                    'trin1278', 'taba1259', ]
COLON_LENGTHENING_LANGUAGES = ['apah1238','movi1243']
APOSTROPHE = [42892, 39, 8217, 700]

def clean_elt(w, langname, typ = 'wd'):
    if langname in APOSTROPHE_GLOTTAL_LANGUAGES and typ in {'wd','mb'}: 
        for cid in APOSTROPHE:
            w = w.replace(chr(cid), 'ʔ')
    if langname in COLON_LENGTHENING_LANGUAGES and typ in {'wd','mb'}: 
        w = w.replace(':',  'ː')
    w = w.strip(PUNCT_WD)
    return w

# %% [markdown]
# ### write master list

# %%
# FOR PS:
ignore_ps = ['apah1238', 'bain1259', 'cabe1245', 'cash1254', 'jeha1242', 'jeju1234','kama1351', 
             'nisv1234', 'orko1234','sumi1235','taba1259']
single_ps = ['dolg1241', 'nort2641', 'nort2875','sanz1248', 'savo1255', 'urum1249'] # all caps, parens, nums
further_check_ps = ['goro1270', 'kaka1265', 'komn1238', 'movi1243', 'ngal1292', 'port1286', 'teop1238', 'trin1278', 'vera1241']
# replace <Not Sure> by  'X', and 'Attaches to any ...' by sth too

# %%
# FOR MB/GL:
# arap follow dashes instead of misalign strategy
# qual control of alignments check gl per mb and see if makes sense when multiple

misalign_docs_mb = ['apah1238', 'arap1274', 'bain1259', 'jeju1234', 'kama1351', 'nort2875', 'orko1234', 'sout2856', 'trin1278', 'urum1249']

# %%
if not os.path.isdir('./generated/'): os.mkdir('./generated/')
if not os.path.isdir('./generated/doreco_morphology'): os.mkdir('./generated/doreco_morphology')

for f in sorted(os.listdir(doreco_folder)):
    if not os.path.isdir(doreco_folder + f): continue
    doc = f.split('_')[1]
    print(f, doc, end = ' ')
    sf = next((fi for fi in os.listdir(doreco_folder + f) if os.path.isdir(doreco_folder + f + '/' + fi)),None)
    if sf == None: break
    df = pd.read_csv(doreco_folder + f + '/' + sf + '/doreco_%s_wd.csv' % doc)
    print(len(df))
    errors = []
    markers = Counter()
    nerrors = 0
    for i,r in df.iterrows():
        wd, mb, ps, gl = r['wd'], r['mb'], r['ps'], r['gl']
        if pd.isna(wd) or pd.isna(mb) or pd.isna(gl) or gl.strip('* -?') == '' or mb.strip('* -?') == '': 
            errors.append({'category':'has nan', 'wd' : wd, 'mb' : mb, 'gl' : gl, 'ps' : ps}); continue
        if pd.isna(ps): ps = ''
        #
        # WD
        wdn = clean_elt(filter_wd(wd, doc).lower(), doc, 'wd')
        if wdn == '': errors.append({'category':'no word', 'wd' : wd, 'mb' : mb, 'gl' : gl, 'ps' : ps}); continue
        #
        # GL and MB
        if 'wordplay' in gl: errors.append({'category':'wordplay', 'wd' : wd, 'mb' : mb, 'gl' : gl, 'ps' : ps}); continue
        mbn = list(filter(lambda x : x != '', map(lambda x : clean_elt(x.lower(), doc, 'mb'), eliminate_asterisks(mb.split(' ')))))
        gln = eliminate_asterisks(map(lambda x : clean_elt(x, doc, 'gl'), gl.split(' ')))
        if len(mbn) < len(gln) and doc in misalign_docs_mb:
            mbc, glc = mb_gl_align(mbn, gln, doc)
        else: mbc, glc = mbn, gln
        if len(mbc) == 0: errors.append({'category':'no mb', 'wd' : wd, 'mb' : mb, 'gl' : gl, 'ps' : ps}); continue
        elif len(glc) == 0: errors.append({'category':'no gl', 'wd' : wd, 'mb' : mb, 'gl' : gl, 'ps' : ps}); continue
        elif len(mbc)!=len(glc): errors.append({'category':'unalignable', 'wd' : wd, 'mb' : mb, 'gl' : gl, 'ps' : ps}); continue
        elif next((True for e in mbc + glc if e == ''),False): errors.append({'category':'unalignable', 'wd' : wd, 'mb' : mb, 'gl' : gl, 'ps' : ps}); continue
        #
        # PS
        psn = eliminate_asterisks(ps.split(' '))
        # if len(psn) != len(mbc) and doc not in ignore_ps + further_check_ps + single_ps: 
        #     errors.append({'category':'no ps', 'wd' : wd, 'mb' : mb, 'gl' : gl, 'ps' : ps}); continue
        ps_good = doc not in ignore_ps + further_check_ps + single_ps
        marker = (wdn, tuple(zip(mbc, glc, (psn if ps_good else ['X']*len(mbc)))))
        markers[marker] += 1
        #if f == 'ngal1292.csv': ps = eliminate_asterisks(ps.split('-')) if not pd.isna(ps) else []
        #else: ps = eliminate_asterisks(ps.split(' ')) if not pd.isna(ps) else []

    print(doc, len(markers))
    if len(markers) == 0: continue
    pd.DataFrame(errors).to_excel('./generated/doreco_morphology/errors_%s.xlsx' % doc)
    with open('./generated/doreco_morphology/%s.master.tsv' % doc, 'w') as fout:
        fout.write('\n'.join(map(lambda x : '%s\t%s\t%d' % 
                                 (x[0][0], ' '.join('%s:%s_%s' % xi for xi in x[0][1]), x[1]),
                                 sorted(markers.items(), key = lambda x : -x[1]))))
    #break
# Out:
# doreco_anal1239_extended_v2.0 anal1239 19014
# anal1239 0
# doreco_apah1238_extended_v2.0 apah1238 20479
# apah1238 3039
# doreco_arap1274_extended_v2.0 arap1274 15541
# arap1274 4667
# doreco_bain1259_extended_v2.0 bain1259 18701
# bain1259 3785
# doreco_beja1238_extended_v2.0 beja1238 20134
# beja1238 8534
# doreco_bora1263_extended_v2.0 bora1263
# /tmp/ipykernel_2596167/3228592141.py:10: DtypeWarning: Columns (8,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(doreco_folder + f + '/' + sf + '/doreco_%s_wd.csv' % doc)
# 48340
# bora1263 12740
# doreco_cabe1245_extended_v2.1 cabe1245 24280
# cabe1245 3727
# doreco_cash1254_extended_v2.0 cash1254 13669
# cash1254 2766
# doreco_dolg1241_extended_v2.0 dolg1241 22301
# dolg1241 6227
# doreco_even1259_extended_v2.0 even1259 14609
# even1259 5723
# doreco_goem1240_extended_v2.0 goem1240 28957
# goem1240 1680
# doreco_goro1270_extended_v2.0 goro1270 26085
# goro1270 5300
# doreco_guri1247_extended_v2.0 guri1247 11127
# guri1247 0
# doreco_hoch1243_extended_v2.0 hoch1243 12523
# hoch1243 2947
# doreco_jeha1242_extended_v2.0 jeha1242 11411
# jeha1242 991
# doreco_jeju1234_extended_v2.0 jeju1234 13264
# jeju1234 3853
# doreco_kaka1265_extended_v2.0 kaka1265 52615
# kaka1265 5167
# doreco_kama1351_extended_v2.1 kama1351 47359
# kama1351 5488
# doreco_kark1256_extended_v2.0 kark1256 13787
# kark1256 0
# doreco_komn1238_extended_v2.0 komn1238 43515
# komn1238 6651
# doreco_ligh1234_extended_v2.0 ligh1234 11265
# ligh1234 0
# doreco_lowe1385_extended_v2.0 lowe1385 14727
# lowe1385 0
# doreco_movi1243_extended_v2.0 movi1243 14554
# movi1243 2456
# doreco_ngal1292_extended_v2.0 ngal1292 6781
# ngal1292 1025
# doreco_nisv1234_extended_v2.0 nisv1234 15028
# nisv1234 3552
# doreco_nngg1234_extended_v2.0 nngg1234 46125
# nngg1234 2437
# doreco_nort2641_extended_v2.0 nort2641 11664
# nort2641 3474
# doreco_nort2875_extended_v2.0 nort2875 14953
# nort2875 2258
# doreco_orko1234_extended_v2.0 orko1234 24178
# orko1234 1601
# doreco_pnar1238_extended_v2.0 pnar1238 22950
# pnar1238 2706
# doreco_port1286_extended_v2.0 port1286 14914
# port1286 1312
# doreco_resi1247_extended_v2.0 resi1247 12117
# resi1247 0
# doreco_ruul1235_extended_v2.0 ruul1235 13675
# ruul1235 4676
# doreco_sadu1234_extended_v2.0 sadu1234 13878
# sadu1234 0
# doreco_sanz1248_extended_v2.0 sanz1248 6870
# sanz1248 1704
# doreco_savo1255_extended_v2.0 savo1255 14464
# savo1255 2253
# doreco_sout2856_extended_v2.0 sout2856 35020
# sout2856 4667
# doreco_sout3282_extended_v2.0 sout3282 41948
# /tmp/ipykernel_2596167/3228592141.py:10: DtypeWarning: Columns (14,17,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(doreco_folder + f + '/' + sf + '/doreco_%s_wd.csv' % doc)
# sout3282 6818
# doreco_stan1290_extended_v2.0 stan1290 16867
# stan1290 0
# doreco_sumi1235_extended_v2.0 sumi1235 16026
# sumi1235 3607
# doreco_svan1243_extended_v2.0 svan1243 13343
# svan1243 0
# doreco_taba1259_extended_v2.0 taba1259 6864
# taba1259 2255
# doreco_teop1238_extended_v2.0 teop1238 15341
# teop1238 1705
# doreco_texi1237_extended_v2.0 texi1237 14571
# texi1237 2087
# doreco_toto1304_extended_v2.0 toto1304 16837
# toto1304 2818
# doreco_trin1278_extended_v2.0 trin1278 24333
# trin1278 5334
# doreco_tsim1256_extended_v2.0 tsim1256 11581
# tsim1256 0
# doreco_urum1249_extended_v2.1 urum1249 26462
# urum1249 6376
# doreco_vera1241_extended_v2.0 vera1241 21663
# vera1241 2723
# doreco_warl1254_extended_v2.0 warl1254 11211
# warl1254 0
# doreco_yong1270_extended_v2.0 yong1270 10035
# yong1270 0
# doreco_yuca1254_extended_v2.0 yuca1254 14223
# yuca1254 0
# doreco_yura1255_extended_v2.0 yura1255 46439
# yura1255 0

# %% [markdown]
# ### bitext generation

# %%
if not os.path.isdir('./generated/doreco_bitexts'): os.mkdir('./generated/doreco_bitexts')

for f in sorted(os.listdir(doreco_folder)):
    all_wds = Counter()
    if not os.path.isdir(doreco_folder + f): continue
    doc = f.split('_')[1]
    print(f, doc, end = ' ')
    sf = next((fi for fi in os.listdir(doreco_folder + f) if os.path.isdir(doreco_folder + f + '/' + fi)),None)
    if sf == None: break
    df = pd.read_csv(doreco_folder + f + '/' + sf + '/doreco_%s_wd.csv' % doc)
    bitext_builder = {}
    ctr = Counter()
    for i,r in df.iterrows():
        wd, ref, ft = r['wd'], r['ref'], r['ft']
        if pd.isna(wd) or ' ' in wd: continue
        wdn = clean_elt(BT(filter_wd(wd, doc)).lower(), doc)
        if wdn == '': continue
        ctr[wdn] += 1
        if pd.isna(ref) or pd.isna(wd) or pd.isna(ft): continue
        if re.match(r'\*+', ft): continue
        
        if wdn == '': continue
        #
        if ref not in bitext_builder: bitext_builder[ref] = [[], list(map(lambda x : x.strip(punct), ft.split()))]
        #
        bitext_builder[ref][0] += [wdn]
    print('%s N lines = %d; N types = %d' %
          (doc, len(bitext_builder), len(set([w for l in bitext_builder.values() for w in l[0]]))))
    if len(bitext_builder) == 0: continue
    with open('./generated/doreco_bitexts/%s.txt' % doc, 'w') as fout:
        fout.write('\n'.join('%s ||| %s' % (' '.join(v[0]), ' '.join(v[1])) for k,v in sorted(bitext_builder.items())))
# Out:
# doreco_anal1239_extended_v2.0 anal1239 anal1239 N lines = 2855; N types = 4043
# doreco_apah1238_extended_v2.0 apah1238 apah1238 N lines = 3268; N types = 2062
# doreco_arap1274_extended_v2.0 arap1274 arap1274 N lines = 3231; N types = 4751
# doreco_bain1259_extended_v2.0 bain1259 bain1259 N lines = 2933; N types = 4583
# doreco_beja1238_extended_v2.0 beja1238 beja1238 N lines = 6330; N types = 7241
# doreco_bora1263_extended_v2.0 bora1263
# /tmp/ipykernel_2596167/3589200480.py:10: DtypeWarning: Columns (8,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(doreco_folder + f + '/' + sf + '/doreco_%s_wd.csv' % doc)
# bora1263 N lines = 4027; N types = 11211
# doreco_cabe1245_extended_v2.1 cabe1245 cabe1245 N lines = 2058; N types = 2863
# doreco_cash1254_extended_v2.0 cash1254 cash1254 N lines = 1767; N types = 3487
# doreco_dolg1241_extended_v2.0 dolg1241 dolg1241 N lines = 2429; N types = 5847
# doreco_even1259_extended_v2.0 even1259 even1259 N lines = 2312; N types = 5171
# doreco_goem1240_extended_v2.0 goem1240 goem1240 N lines = 2606; N types = 1381
# doreco_goro1270_extended_v2.0 goro1270 goro1270 N lines = 4333; N types = 4612
# doreco_guri1247_extended_v2.0 guri1247 guri1247 N lines = 1326; N types = 2203
# doreco_hoch1243_extended_v2.0 hoch1243 hoch1243 N lines = 972; N types = 2802
# doreco_jeha1242_extended_v2.0 jeha1242 jeha1242 N lines = 1332; N types = 1358
# doreco_jeju1234_extended_v2.0 jeju1234 jeju1234 N lines = 1973; N types = 3773
# doreco_kaka1265_extended_v2.0 kaka1265 kaka1265 N lines = 4610; N types = 4608
# doreco_kama1351_extended_v2.1 kama1351 kama1351 N lines = 9099; N types = 6422
# doreco_kark1256_extended_v2.0 kark1256 kark1256 N lines = 1794; N types = 4057
# doreco_komn1238_extended_v2.0 komn1238 komn1238 N lines = 7521; N types = 5750
# doreco_ligh1234_extended_v2.0 ligh1234 ligh1234 N lines = 1438; N types = 1494
# doreco_lowe1385_extended_v2.0 lowe1385 lowe1385 N lines = 1150; N types = 2304
# doreco_movi1243_extended_v2.0 movi1243 movi1243 N lines = 2195; N types = 2667
# doreco_ngal1292_extended_v2.0 ngal1292 ngal1292 N lines = 1682; N types = 1651
# doreco_nisv1234_extended_v2.0 nisv1234 nisv1234 N lines = 1868; N types = 2475
# doreco_nngg1234_extended_v2.0 nngg1234 nngg1234 N lines = 5935; N types = 2003
# doreco_nort2641_extended_v2.0 nort2641 nort2641 N lines = 834; N types = 2216
# doreco_nort2875_extended_v2.0 nort2875 nort2875 N lines = 2695; N types = 2209
# doreco_orko1234_extended_v2.0 orko1234 orko1234 N lines = 2940; N types = 2100
# doreco_pnar1238_extended_v2.0 pnar1238 pnar1238 N lines = 972; N types = 2600
# doreco_port1286_extended_v2.0 port1286 port1286 N lines = 1220; N types = 1018
# doreco_resi1247_extended_v2.0 resi1247 resi1247 N lines = 1248; N types = 2971
# doreco_ruul1235_extended_v2.0 ruul1235 ruul1235 N lines = 2906; N types = 4241
# doreco_sadu1234_extended_v2.0 sadu1234 sadu1234 N lines = 1490; N types = 1121
# doreco_sanz1248_extended_v2.0 sanz1248 sanz1248 N lines = 460; N types = 2400
# doreco_savo1255_extended_v2.0 savo1255 savo1255 N lines = 780; N types = 1613
# doreco_sout2856_extended_v2.0 sout2856 sout2856 N lines = 1647; N types = 3028
# doreco_sout3282_extended_v2.0 sout3282
# /tmp/ipykernel_2596167/3589200480.py:10: DtypeWarning: Columns (14,17,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(doreco_folder + f + '/' + sf + '/doreco_%s_wd.csv' % doc)
# sout3282 N lines = 2281; N types = 3475
# doreco_stan1290_extended_v2.0 stan1290 stan1290 N lines = 0; N types = 0
# doreco_sumi1235_extended_v2.0 sumi1235 sumi1235 N lines = 2478; N types = 3375
# doreco_svan1243_extended_v2.0 svan1243 svan1243 N lines = 1301; N types = 4586
# doreco_taba1259_extended_v2.0 taba1259 taba1259 N lines = 632; N types = 1881
# doreco_teop1238_extended_v2.0 teop1238 teop1238 N lines = 1989; N types = 1153
# doreco_texi1237_extended_v2.0 texi1237 texi1237 N lines = 2824; N types = 1974
# doreco_toto1304_extended_v2.0 toto1304 toto1304 N lines = 3697; N types = 2972
# doreco_trin1278_extended_v2.0 trin1278 trin1278 N lines = 2007; N types = 5421
# doreco_tsim1256_extended_v2.0 tsim1256 tsim1256 N lines = 1596; N types = 3185
# doreco_urum1249_extended_v2.1 urum1249 urum1249 N lines = 2308; N types = 5772
# doreco_vera1241_extended_v2.0 vera1241 vera1241 N lines = 1938; N types = 1801
# doreco_warl1254_extended_v2.0 warl1254 warl1254 N lines = 2012; N types = 2222
# doreco_yong1270_extended_v2.0 yong1270 yong1270 N lines = 865; N types = 2323
# doreco_yuca1254_extended_v2.0 yuca1254 yuca1254 N lines = 994; N types = 2278
# doreco_yura1255_extended_v2.0 yura1255 yura1255 N lines = 14568; N types = 7720

# %% [markdown]
# ## spacy English

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
english_ft = list(map(lambda l : l.strip('\n'), open('./doreco_doculects.txt').readlines()))
for lg in english_ft:
    new_bit = []
    for li,l in enumerate(open('./generated/doreco_bitexts/%s.txt' % lg).readlines()):
        spacied = ['/'.join(map(lambda e : str(e).replace('/','#').replace(' ', '#'), [w.text, w.i, w.lemma_, w.pos_, w.tag_, w.dep_, w.head.i]))
                   for w in nlp(l.strip('\n').split(' ||| ')[1])]
        new_bit.append((l.strip('\n').split(' ||| ')[0], ' '.join(spacied)))
        if li % 500 == 0: print(lg, li, new_bit[-1])
    with open('./generated/doreco_bitexts/%s.spc' % lg, 'w') as fout:
        fout.write('\n'.join('%s ||| %s' % ln for ln in new_bit))
# Out:
# apah1238 0 ('mm', 'mm/0/mm/PROPN/NNP/ROOT/0')
# apah1238 500 ('hubula fil were', 'is/0/be/AUX/VBZ/ROOT/0 on/1/on/ADP/IN/prep/0 the/2/the/DET/DT/det/4 western/3/western/ADJ/JJ/amod/4 side/4/side/NOUN/NN/pobj/1')
# apah1238 1000 ('winahik fikit te', 'towards/0/towards/ADP/IN/ROOT/0 Mount/1/Mount/PROPN/NNP/compound/2 Wenahik/2/Wenahik/PROPN/NNP/pobj/0')
# apah1238 1500 ('yu', 'ya/0/ya/PRON/PRP/ROOT/0')
# apah1238 2000 ('ubalik itno kuruk lit hibareg he eke at', 'Mr/0/Mr/PROPN/NNP/compound/1 Ubalik/1/Ubalik/PROPN/NNP/nsubj/2 saw/2/see/VERB/VBD/ROOT/2 a/3/a/DET/DT/det/4 woman/4/woman/NOUN/NN/dobj/2')
# apah1238 2500 ('esetuk', 'cook/0/cook/VERB/VB/ROOT/0')
# apah1238 3000 ('it obog toho', 'everybody/0/everybody/PRON/NN/ROOT/0')
# anal1239 0 ('anal jeral', 'Anal/0/anal/ADJ/JJ/amod/1 proverbs/1/proverb/NOUN/NNS/ROOT/1')
# anal1239 500 ('vahmi khol thung tingnǟl eh din chee choo nu̠', 'There/0/there/PRON/EX/expl/1 are/1/be/VERB/VBP/ROOT/1 lots/2/lot/NOUN/NNS/attr/1 of/3/of/ADP/IN/prep/2 earthworms/4/earthworm/NOUN/NNS/pobj/3 inside/5/inside/ADP/IN/prep/4 her/6/her/PRON/PRP$/poss/7 eyeholes/7/eyehole/NOUN/NNS/pobj/5')
# anal1239 1000 ('leha vanu̠ meeting toh vaṭo val je', 'he/0/he/PRON/PRP/nsubj/1 went/1/go/VERB/VBD/ROOT/1 far/2/far/ADV/RB/advmod/3 away/3/away/ADV/RB/advmod/1 and/4/and/CCONJ/CC/cc/1 had/5/have/VERB/VBD/conj/1 a/6/a/DET/DT/det/7 meeting/7/meeting/NOUN/NN/dobj/5')
# anal1239 1500 ('sinnu̠ maṭumnu̠ kanali oh chara kǟṭhope naka ve datinu̠', 'you/0/you/PRON/PRP/nsubj/1 told/1/tell/VERB/VBD/ROOT/1 me/2/I/PRON/PRP/dobj/1 that/3/that/SCONJ/IN/mark/10 the/4/the/DET/DT/det/6 youngest/5/young/ADJ/JJS/amod/6 girl/6/girl/NOUN/NN/nsubj/10 you/7/you/PRON/PRP/nsubj/8 married/8/marry/VERB/VBD/relcl/6 will/9/will/AUX/MD/aux/10 concieve/10/concieve/VERB/VB/ccomp/1 a/11/a/DET/DT/det/12 child/12/child/NOUN/NN/dobj/10')
# anal1239 2000 ('dọnǟte tuthung rahtuwng', 'at/0/at/ADP/IN/ROOT/0 that/1/that/DET/DT/det/2 moment/2/moment/NOUN/NN/pobj/0')
# anal1239 2500 ('dọnǟte pa paṭhama paṭhama akol akol akol dọnu̠', "father/0/father/PROPN/NNP/nsubj/3 do/1/do/AUX/VBP/aux/3 n't/2/not/PART/RB/neg/3 release/3/release/VERB/VB/ROOT/3 her/4/her/PRON/PRP$/dobj/3 keep/5/keep/VERB/VB/dobj/3 hugging/6/hug/VERB/VBG/xcomp/5 her/7/she/PRON/PRP/dobj/6")
# arap1274 0 ('heʔihʔini nihʔoo3oo cebisee', 'Trickster/0/trickster/NOUN/NN/nsubj/2 was/1/be/AUX/VBD/aux/2 walking/2/walk/VERB/VBG/ROOT/2 along/3/along/ADP/IN/advmod/2')
# arap1274 500 ('heebeexehneeʔeesoo nosouniihiʔ', 'It/0/it/PRON/PRP/nsubj/2 should/1/should/AUX/MD/aux/2 be/2/be/AUX/VB/ROOT/2 that/3/that/DET/DT/det/4 way/4/way/NOUN/NN/attr/2 still/5/still/ADV/RB/advmod/2 from/6/from/ADP/IN/prep/5 now/7/now/ADV/RB/pcomp/6 on/8/on/ADV/RB/advmod/2')
# arap1274 1000 ('heniisiiteno ceeseʔ', '“/0/"/PUNCT/``/punct/3 I/1/I/PRON/PRP/nsubj/3 have/2/have/AUX/VBP/aux/3 caught/3/catch/VERB/VBN/ROOT/3 one/4/one/NUM/CD/dobj/3')
# arap1274 1500 ('hee nihʔii3oʔ', 'Yeah/0/yeah/INTJ/UH/intj/2 I/1/I/PRON/PRP/nsubj/2 said/2/say/VERB/VBD/ROOT/2 to/3/to/ADP/IN/prep/2 him/4/he/PRON/PRP/pobj/3')
# arap1274 2000 ('neheʔ biikouniisiis netesihʔe neneenit nihʔiit', 'The/0/the/DET/DT/det/1 moon/1/moon/NOUN/NN/npadvmod/5 my/2/my/PRON/PRP$/poss/3 wife/3/wife/NOUN/NN/appos/1 she/4/she/PRON/PRP/nsubj/5 is/5/be/AUX/VBZ/ROOT/5 the/6/the/DET/DT/det/7 one/7/one/NOUN/NN/attr/5 he/8/he/PRON/PRP/nsubj/9 said/9/say/VERB/VBD/relcl/7')
# arap1274 2500 ('wohei neeʔeeneesooʔ nuhuʔ', "Well/0/well/INTJ/UH/intj/2 that/1/that/PRON/DT/nsubj/2 's/2/be/AUX/VBZ/ROOT/2 how/3/how/SCONJ/WRB/advmod/5 this/4/this/PRON/DT/nsubj/5 happened/5/happen/VERB/VBD/ccomp/2")
# arap1274 3000 ('teesisee3iʔ', 'They/0/they/PRON/PRP/nsubj/1 got/1/get/VERB/VBD/ROOT/1 on/2/on/ADP/IN/prep/1 their/3/their/PRON/PRP$/poss/4 horses/4/horse/NOUN/NNS/pobj/2')
# beja1238 0 ('tak', 'A/0/a/DET/DT/det/1 man/1/man/NOUN/NN/ROOT/1 :/2/:/PUNCT/:/punct/1')
# beja1238 500 ('eːkoːreː', 'His/0/his/PRON/PRP$/poss/1 saddle/1/saddle/NOUN/NN/ROOT/1')
# beja1238 1000 ('hireːreː', 'while/0/while/SCONJ/IN/mark/1 walking/1/walk/VERB/VBG/ROOT/1')
# beja1238 1500 ('mhalle igirʃeː ʔare', 'from/0/from/ADP/IN/prep/5 the/1/the/DET/DT/det/3 two/2/two/NUM/CD/nummod/3 pennies/3/penny/NOUN/NNS/pobj/0 his/4/his/PRON/PRP$/poss/5 children/5/child/NOUN/NNS/ROOT/5')
# beja1238 2000 ('tikamteː ontʔa', 'his/0/his/PRON/PRP$/poss/1 she/1/she/NOUN/NN/compound/3 -/2/-/PUNCT/HYPH/punct/3 camels/3/camel/NOUN/NNS/ROOT/3 now/4/now/ADV/RB/advmod/3')
# beja1238 2500 ('bak tʔiːteːna', 'Something/0/something/PRON/NN/ROOT/0 like/1/like/ADP/IN/prep/0 that/2/that/PRON/DT/pobj/1')
# beja1238 3000 ('liːgamanaːti liːgami eːnhoːb', 'when/0/when/SCONJ/WRB/advmod/2 they/1/they/PRON/PRP/nsubj/2 said/2/say/VERB/VBD/advcl/5 :/3/:/PUNCT/:/punct/2 Overlooker/4/Overlooker/PROPN/NNP/compound/5 overlook/5/overlook/NOUN/NN/ROOT/5')
# beja1238 3500 ('isenna eːn', 'they/0/they/PRON/PRP/nsubj/1 found/1/find/VERB/VBD/ROOT/1 they/2/they/PRON/PRP/nsubj/3 said/3/say/VERB/VBD/ccomp/1')
# beja1238 4000 ('tibarijeːna baːraːta', "do/0/do/AUX/VBP/aux/2 n't/1/not/PART/RB/neg/2 ask/2/ask/VERB/VB/ROOT/2 for/3/for/ADP/IN/prep/2 what/4/what/PRON/WP/dobj/6 you/5/you/PRON/PRP/nsubj/6 have/6/have/AUX/VBP/pcomp/3")
# beja1238 4500 ('dangarti girmaj', 'at/0/at/ADP/IN/ROOT/0 the/1/the/DET/DT/det/2 beginning/2/beginning/NOUN/NN/pobj/0 of/3/of/ADP/IN/prep/2 the/4/the/DET/DT/det/5 racetrack/5/racetrack/NOUN/NN/pobj/3')
# beja1238 5000 ('naːtk ʔimbateː hasamijeːb oːdoːr', 'when/0/when/SCONJ/WRB/advmod/2 he/1/he/PRON/PRP/nsubj/2 went/2/go/VERB/VBD/ROOT/2 past/3/past/ADP/IN/prep/2 all/4/all/DET/PDT/predet/6 these/5/these/DET/DT/det/6 things/6/thing/NOUN/NNS/pobj/3')
# beja1238 5500 ('talʔamiːn eː', 'they/0/they/PRON/PRP/nsubj/1 peeped/1/peep/VERB/VBD/ROOT/1 they/2/they/PRON/PRP/nsubj/3 said/3/say/VERB/VBD/parataxis/1')
# beja1238 6000 ('hummadid', 'to/0/to/ADP/IN/ROOT/0 Hummad/1/Hummad/PROPN/NNP/pobj/0')
# cabe1245 0 ('ñãjĩñã jiewa sẽrgẽ je rö kal digina', 'Long/0/long/ADV/RB/advmod/1 ago/1/ago/ADV/RB/advmod/3 they/2/they/PRON/PRP/nsubj/3 lived/3/live/VERB/VBD/ROOT/3 under/4/under/ADP/IN/prep/3 the/5/the/DET/DT/det/6 trees/6/tree/NOUN/NNS/pobj/4')
# cabe1245 500 ('se bötögeũte dögeũnẽ egla kieite kã kiegẽite kal kate keyege kiegẽite rancho kabekar', 'We/0/we/PRON/PRP/nsubj/1 come/1/come/VERB/VBP/ccomp/10 and/2/and/CCONJ/CC/cc/1 get/3/get/VERB/VB/conj/1 to/4/to/ADP/IN/prep/3 a/5/a/DET/DT/det/6 place/6/place/NOUN/NN/pobj/4 called/7/call/VERB/VBN/acl/6 #/8/#/PUNCT/NFP/punct/1 there/9/there/PRON/EX/expl/10 is/10/be/VERB/VBZ/ROOT/10 a/11/a/DET/DT/det/13 big/12/big/ADJ/JJ/amod/13 house/13/house/NOUN/NN/attr/10 called/14/call/VERB/VBN/acl/13 Rancho/15/Rancho/PROPN/NNP/compound/16 Cabear/16/Cabear/PROPN/NNP/oprd/14')
# cabe1245 1000 ('jeskanẽ mãga kuchi yabla chi jalali nẽ jiñõgẽnẽ jinõgẽ ĩã nẽ', 'Then/0/then/ADV/RB/advmod/6 the/1/the/DET/DT/det/4 fucking/2/fucking/ADJ/JJ/amod/4 little/3/little/ADJ/JJ/amod/4 pigs/4/pig/NOUN/NNS/nsubj/6 were/5/be/AUX/VBD/aux/6 laughing/6/laugh/VERB/VBG/ROOT/6 and/7/and/CCONJ/CC/cc/6 playing/8/play/VERB/VBG/conj/6 too/9/too/ADV/RB/advmod/8')
# cabe1245 1500 ('kayue juela bi í jueiglö desãũte ñerö', 'it/0/it/PRON/PRP/nsubj/1 is/1/be/AUX/VBZ/ROOT/1 incredible/2/incredible/ADJ/JJ/acomp/1 but/3/but/CCONJ/CC/cc/1 his/4/his/PRON/PRP$/poss/5 spirit/5/spirit/NOUN/NN/nsubj/6 went/6/go/VERB/VBD/conj/1 out/7/out/ADP/RP/prt/6')
# cabe1245 2000 ('koyirgatenẽ mãga jeska se je tí sũẽra lobo bi nẽ desãunẽ í wömĩ nẽ', 'They/0/they/PRON/PRP/nsubj/1 made/1/make/VERB/VBD/ROOT/1 noise/2/noise/NOUN/NN/dobj/1 and/3/and/CCONJ/CC/cc/1 then/4/then/ADV/RB/advmod/7 a/5/a/DET/DT/det/6 wolf/6/wolf/NOUN/NN/nsubj/7 appeared/7/appear/VERB/VBD/conj/1 before/8/before/ADP/IN/prep/7 them/9/they/PRON/PRP/pobj/8')
# cash1254 0 ('haska waabidan hiweken haskai hiweabu', 'He/0/he/PRON/PRP/nsubj/1 lived/1/live/VERB/VBD/ROOT/1 like/2/like/ADP/IN/prep/1 that/3/that/SCONJ/IN/mark/5 they/4/they/PRON/PRP/nsubj/5 lived/5/live/VERB/VBD/pcomp/2 like/6/like/ADP/IN/prep/5 that/7/that/PRON/DT/pobj/6')
# cash1254 500 ('hanuxun nuku yuiniki', 'then/0/then/ADV/RB/advmod/2 he/1/he/PRON/PRP/nsubj/2 warned/2/warn/VERB/VBD/ROOT/2 us/3/we/PRON/PRP/dobj/2')
# cash1254 1000 ('na nawa nukuanu dayaibuima yukakin hi yukaikin', 'The/0/the/DET/DT/det/4 non/1/non/ADJ/JJ/amod/4 -/2/-/ADJ/JJ/amod/4 indigenous/3/indigenous/ADJ/JJ/amod/4 people/4/people/NOUN/NNS/nsubj/10 who/5/who/PRON/WP/nsubj/6 worked/6/work/VERB/VBD/relcl/4 on/7/on/ADP/IN/prep/6 our/8/our/PRON/PRP$/poss/9 land/9/land/NOUN/NN/pobj/7 asked/10/ask/VERB/VBD/ROOT/10 me/11/I/PRON/PRP/dobj/10 asked/12/ask/VERB/VBD/ccomp/10 me/13/I/PRON/PRP/dobj/12 to/14/to/PART/TO/aux/15 work/15/work/VERB/VB/xcomp/12 with/16/with/ADP/IN/prep/15 trees/17/tree/NOUN/NNS/pobj/16')
# cash1254 1500 ('hanua en comercial marselinun en entreganiki', 'then/0/then/ADV/RB/advmod/2 I/1/I/PRON/PRP/nsubj/2 handed/2/hand/VERB/VBD/ROOT/2 over/3/over/ADP/RP/prt/2 the/4/the/DET/DT/det/5 business/5/business/NOUN/NN/dobj/2 to/6/to/ADP/IN/prep/2 Marcelino/7/Marcelino/PROPN/NNP/pobj/6')
# dolg1241 0 ('sad ah sad sadovnik sadovnik grušalarɨ komujar', 'A/0/a/DET/DT/det/1 gardener/1/gardener/NOUN/NN/nsubj/3 is/2/be/AUX/VBZ/aux/3 collecting/3/collect/VERB/VBG/ROOT/3 pears/4/pear/NOUN/NNS/dobj/3')
# dolg1241 500 ('dʼe on ol ihin de itinne ulakan bagaj dʼe kalxµos bµolla', 'And/0/and/CCONJ/CC/cc/6 therefore/1/therefore/ADV/RB/advmod/6 a/2/a/DET/DT/det/5 very/3/very/ADV/RB/advmod/4 big/4/big/ADJ/JJ/amod/5 kolkhoz/5/kolkhoz/NOUN/NN/nsubj/6 came/6/come/VERB/VBD/ROOT/6 into/7/into/ADP/IN/prep/6 being/8/be/AUX/VBG/pcomp/7 there/9/there/ADV/RB/advmod/8')
# dolg1241 1000 ('maršrut köröllör taba törötörüger kalkalaːk hirinen ohuːrdaːk hirinen kajalardaːk hirderinen ürekterdeːk hirderinen', 'The/0/the/DET/DT/det/1 route/1/route/NOUN/NN/nsubjpass/9 for/2/for/ADP/IN/prep/1 the/3/the/DET/DT/det/4 calving/4/calving/NOUN/NN/pobj/2 of/5/of/ADP/IN/prep/4 the/6/the/DET/DT/det/7 reindeer/7/reindeer/NOUN/NN/pobj/5 is/8/be/AUX/VBZ/auxpass/9 chosen/9/choose/VERB/VBN/ROOT/9 along/10/along/ADP/IN/prep/9 protected/11/protect/VERB/VBN/amod/12 places/12/place/NOUN/NNS/pobj/10 forested/13/forest/VERB/VBN/acl/12 places/14/place/NOUN/NNS/dobj/13 mountainous/15/mountainous/ADJ/JJ/amod/16 places/16/place/NOUN/NNS/dobj/13 and/17/and/CCONJ/CC/cc/16 places/18/place/NOUN/NNS/conj/16 with/19/with/ADP/IN/prep/13 rivers/20/river/NOUN/NNS/pobj/19')
# dolg1241 1500 ('onton tɨːhɨčča togus hüːs otut hettis dʼɨla bµolarɨgar dʼe tajmɨːrɨŋ dʼonnoro dʼe haŋardɨː galasavajdɨːllar vʼerxovnɨj savʼetka sssr bµolarɨgar', 'Then/0/then/ADV/RB/advmod/9 when/1/when/SCONJ/WRB/advmod/5 the/2/the/DET/DT/det/3 year/3/year/NOUN/NN/nsubj/5 1937/4/1937/NUM/CD/appos/3 came/5/come/VERB/VBD/advcl/9 the/6/the/DET/DT/det/8 Taymyr/7/Taymyr/PROPN/NNP/compound/8 people/8/people/NOUN/NNS/nsubj/9 voted/9/vote/VERB/VBD/ROOT/9 for/10/for/ADP/IN/prep/9 the/11/the/DET/DT/det/13 Supreme/12/Supreme/PROPN/NNP/compound/13 Soviet/13/Soviet/PROPN/NNP/pobj/10 for/14/for/ADP/IN/prep/9 the/15/the/DET/DT/det/17 first/16/first/ADJ/JJ/amod/17 time/17/time/NOUN/NN/pobj/14 since/18/since/SCONJ/IN/mark/23 the/19/the/DET/DT/det/20 USSR/20/USSR/PROPN/NNP/nsubjpass/23 had/21/have/AUX/VBD/aux/23 been/22/be/AUX/VBN/auxpass/23 founded/23/found/VERB/VBN/advcl/9')
# dolg1241 2000 ('onton eː srazu bȋes ɨjɨ hɨttɨm da dʼȋem dȋek ɨːppɨttara', 'Then/0/then/ADV/RB/advmod/7 eh/1/eh/INTJ/UH/intj/7 immediately/2/immediately/ADV/RB/advmod/3 five/3/five/NUM/CD/nummod/4 months/4/month/NOUN/NNS/npadvmod/7 I/5/I/PRON/PRP/nsubj/7 was/6/be/AUX/VBD/aux/7 lying/7/lie/VERB/VBG/ccomp/11 there/8/there/ADV/RB/advmod/7 then/9/then/ADV/RB/advmod/11 they/10/they/PRON/PRP/nsubj/11 sent/11/send/VERB/VBD/ROOT/11 me/12/I/PRON/PRP/dative/11 home/13/home/NOUN/NN/dobj/11')
# even1259 0 ('amī minə tərūttan guləldulō', 'My/0/my/PRON/PRP$/poss/1 father/1/father/NOUN/NN/nsubj/2 called/2/call/VERB/VBD/ROOT/2 me/3/I/PRON/PRP/dobj/2 to/4/to/ADP/IN/prep/2 the/5/the/DET/DT/det/6 settlement/6/settlement/NOUN/NN/pobj/4 [/7/[/X/XX/nmod/9 Sovetskaya/8/Sovetskaya/PROPN/NNP/compound/9 Rechka/9/Rechka/PROPN/NNP/appos/6 ]/10/]/PUNCT/-RRB-/punct/2')
# even1259 500 ('ō sōt təpkəməl təpkəməl pankagiril', '“/0/"/PUNCT/``/punct/4 Oh/1/oh/INTJ/UH/intj/3 very/2/very/ADV/RB/advmod/3 shouty/3/shouty/ADJ/JJ/amod/4 Pankagirs/4/Pankagirs/PROPN/NNP/ROOT/4 ./5/./PUNCT/./punct/4 ”/6/"/PUNCT/\'\'/punct/4')
# even1259 1000 ('ərə nu ama uže ororwi tīnčo uže', 'Grandpa/0/Grandpa/PROPN/NNP/nsubj/3 had/1/have/AUX/VBD/aux/3 already/2/already/ADV/RB/advmod/3 let/3/let/VERB/VB/ROOT/3 the/4/the/DET/DT/det/5 reindeer/5/reindeer/NOUN/NN/nsubj/6 go/6/go/VERB/VB/ccomp/3')
# even1259 1500 ('nu ullə kańešna ollol tə tuγə', 'Well/0/well/INTJ/UH/intj/1 meat/1/meat/NOUN/NN/ROOT/1 of/2/of/ADP/IN/prep/1 course/3/course/NOUN/NN/compound/4 fish/4/fish/NOUN/NN/pobj/2 and/5/and/CCONJ/CC/cc/1 that/6/that/SCONJ/IN/conj/1')
# even1259 2000 ('bəjəl ustatintə ganalčil ustatin luporōtčal', 'People/0/People/NOUN/NNS/nsubj/5 all/1/all/DET/PDT/predet/3 the/2/the/DET/DT/det/3 archers/3/archer/NOUN/NNS/appos/0 all/4/all/PRON/DT/appos/3 jumped/5/jump/VERB/VBD/ROOT/5 out/6/out/ADP/RP/prt/5 into/7/into/ADP/IN/prep/5 the/8/the/DET/DT/det/9 street/9/street/NOUN/NN/pobj/7')
# goem1240 0 ('hen tʔong para ʔa ndoe kʔwal bʔak le', 'I/0/I/PRON/PRP/nsubj/2 will/1/will/AUX/MD/aux/2 begin/2/begin/VERB/VB/ROOT/2 a/3/a/DET/DT/det/4 story/4/story/NOUN/NN/dobj/2 here/5/here/ADV/RB/advmod/2 a/6/a/DET/DT/det/8 little/7/little/ADJ/JJ/amod/8 one/8/one/NUM/CD/npadvmod/2')
# goem1240 500 ('ni hoom mmuk a bʔaal', 'She/0/she/PRON/PRP/nsubj/1 held/1/hold/VERB/VBD/ROOT/1 for/2/for/ADP/IN/prep/1 her/3/her/PRON/PRP$/poss/4 own/4/own/ADJ/JJ/pobj/2 a/5/a/DET/DT/det/6 stick/6/stick/NOUN/NN/dobj/1')
# goem1240 1000 ('a boelat kuthoe', 'This/0/this/PRON/DT/nsubj/1 is/1/be/AUX/VBZ/ROOT/1 the/2/the/DET/DT/det/3 end/3/end/NOUN/NN/attr/1 of/4/of/ADP/IN/prep/3 my/5/my/PRON/PRP$/poss/6 speech/6/speech/NOUN/NN/pobj/4')
# goem1240 1500 ('nda noe / kʔyap hen', 'My/0/my/PRON/PRP$/poss/1 father/1/father/NOUN/NN/nsubj/2 scolded/2/scold/VERB/VBD/ROOT/2 me/3/I/PRON/PRP/dobj/2')
# goem1240 2000 ('byaap fyal tʔa nwus', 'The/0/the/DET/DT/det/1 pumpkin/1/pumpkin/NOUN/NN/ROOT/1 boiled/2/boil/VERB/VBD/acl/1 and/3/and/CCONJ/CC/cc/2 fell/4/fall/VERB/VBD/conj/2 into/5/into/ADP/IN/prep/4 the/6/the/DET/DT/det/7 fire/7/fire/NOUN/NN/pobj/5')
# goem1240 2500 ('dʔa goe lap sool hok / tʔong goe dʔu pûanang', 'When/0/when/SCONJ/WRB/advmod/2 you/1/you/PRON/PRP/nsubj/2 receive/2/receive/VERB/VBP/ROOT/2 the/3/the/DET/DT/det/4 money/4/money/NOUN/NN/dobj/2 you/5/you/PRON/PRP/nsubj/7 should/6/should/AUX/MD/aux/7 keep/7/keep/VERB/VB/relcl/4 it/8/it/PRON/PRP/dobj/7 there/9/there/ADV/RB/advmod/7')
# goro1270 0 ('gár ni axwesinta slaaʔ a gawá daandó danú', 'the/0/the/DET/DT/det/1 thing/1/thing/NOUN/NN/nsubj/7 I/2/I/PRON/PRP/nsubj/3 want/3/want/VERB/VBP/relcl/1 to/4/to/PART/TO/aux/5 talk/5/talk/VERB/VB/xcomp/3 about/6/about/ADP/IN/prep/5 is/7/be/AUX/VBZ/ROOT/7 honey/8/honey/NOUN/NN/attr/7')
# goro1270 500 ('aʔa dóʔ qutaduwookáng', "no/0/no/INTJ/UH/intj/3 -/1/-/PUNCT/:/punct/3 it/2/it/PRON/PRP/nsubj/3 's/3/be/AUX/VBZ/ROOT/3 not/4/not/PART/RB/neg/3 the/5/the/DET/DT/det/6 house/6/house/NOUN/NN/attr/3 of/7/of/ADP/IN/prep/6 Qutadu/8/Qutadu/PROPN/NNP/pobj/7")
# goro1270 1000 ('ee', 'yes/0/yes/INTJ/UH/ROOT/0')
# goro1270 1500 ('garí aqo doloodeká', 'this/0/this/DET/DT/det/1 thing/1/thing/NOUN/NN/nsubj/2 is/2/be/AUX/VBZ/ROOT/2 not/3/not/PART/RB/neg/2 a/4/a/DET/DT/det/6 </5/</X/FW/nmod/6 doloód/6/doloód/X/FW/attr/2 >/7/>/X/ADD/punct/2')
# goro1270 2000 ('asma aako kaahh garma kaahh', 'becuse/0/becuse/VERB/VB/advcl/6 there/1/there/PRON/EX/expl/2 is/2/be/VERB/VBZ/ccomp/0 no/3/no/DET/DT/det/4 father/4/father/NOUN/NN/attr/2 there/5/there/PRON/EX/expl/6 is/6/be/VERB/VBZ/ROOT/6 no/7/no/DET/DT/det/8 son/8/son/NOUN/NN/attr/6')
# goro1270 2500 ('looʕi ngiwa hheʔeés tsuunqaroo naʕaa nguna báy looʕirí ohee', 'the/0/the/DET/DT/det/1 leaf/1/leaf/NOUN/NN/nsubjpass/7 when/2/when/SCONJ/WRB/advmod/4 he/3/he/PRON/PRP/nsubj/4 i.e/4/i.e/VERB/VBZ/advcl/1 Haymú/5/Haymú/PROPN/NNP/dobj/4 was/6/be/AUX/VBD/auxpass/7 finished/7/finish/VERB/VBN/ROOT/7 bewitching/8/bewitch/VERB/VBG/xcomp/7 it/9/it/PRON/PRP/dobj/8 he/10/he/PRON/PRP/nsubj/11 say/11/say/VERB/VBP/parataxis/7 to/12/to/ADP/IN/prep/11 Na/13/Na/PROPN/NNP/compound/15 #/14/#/SYM/SYM/punct/15 aa/15/aa/PROPN/NNP/pobj/12 hold/16/hold/VERB/VBP/conj/7 this/17/this/DET/DT/det/18 leaf/18/leaf/NOUN/NN/dobj/16')
# goro1270 3000 ('ee', 'yes/0/yes/INTJ/UH/ROOT/0')
# goro1270 3500 ('kuúng bara hardát hareerók bará doʔ an idoriwa bét', 'when/0/when/SCONJ/WRB/advmod/2 you/1/you/PRON/PRP/nsubj/2 arrived/2/arrive/VERB/VBD/advcl/5 your/3/your/PRON/PRP$/poss/4 wife/4/wife/NOUN/NN/nsubj/5 was/5/be/AUX/VBD/ROOT/5 in/6/in/ADP/IN/prep/5 the/7/the/DET/DT/det/8 house/8/house/NOUN/NN/pobj/6 you/9/you/PRON/PRP/nsubj/11 would/10/would/AUX/MD/aux/11 say/11/say/VERB/VB/parataxis/5 in/12/in/ADP/IN/prep/11 this/13/this/DET/DT/det/14 way/14/way/NOUN/NN/pobj/12')
# goro1270 4000 ('ki qwareesi', 'that/0/that/SCONJ/IN/mark/3 they/1/they/PRON/PRP/nsubjpass/3 are/2/be/AUX/VBP/auxpass/3 lost/3/lose/VERB/VBN/ROOT/3')
# guri1247 0 ('wartayi', 'Hey/0/hey/INTJ/UH/ROOT/0')
# guri1247 500 ('yu bin habim tanku ngurla marni', 'Have/0/have/AUX/VBP/aux/2 you/1/you/PRON/PRP/nsubj/2 had/2/have/VERB/VBN/ccomp/9 a/3/a/DET/DT/det/4 bite/4/bite/NOUN/NN/dobj/2 to/5/to/PART/TO/aux/6 eat/6/eat/VERB/VB/acl/4 Gordon/7/Gordon/PROPN/NNP/compound/8 Stott/8/Stott/PROPN/NNP/nsubj/9 said/9/say/VERB/VBD/ROOT/9 to/10/to/ADP/IN/prep/9 him/11/he/PRON/PRP/pobj/10')
# guri1247 1000 ('fridayla fridayla', 'On/0/on/ADP/IN/prep/4 Friday/1/Friday/PROPN/NNP/pobj/0 at/2/at/ADP/IN/prep/0 Limbunya/3/Limbunya/PROPN/NNP/pobj/2 too/4/too/ADV/RB/ROOT/4')
# hoch1243 0 ('ahm hąąpteʔe ʔeeja wąąkra nąąc stookįįreanąga ahm ʔeeja waracga nąąkšąną', 'Today/0/today/NOUN/NN/npadvmod/4 the/1/the/DET/DT/det/2 men/2/man/NOUN/NNS/nsubj/4 all/3/all/PRON/DT/appos/2 gathered/4/gather/VERB/VBD/ccomp/8 there/5/there/ADV/RB/advmod/4 they/6/they/PRON/PRP/nsubj/8 are/7/be/AUX/VBP/aux/8 drinking/8/drink/VERB/VBG/ROOT/8')
# hoch1243 500 ('hihą hegų heesge haakje hegų eeja tʼąątʼąp wašjįkįka reešgųnį hegų nąąxaamąnį anąga eeja haruceanąga hegų', 'Ok/0/ok/INTJ/UH/intj/3 I/1/I/PRON/PRP/nsubj/3 ’ll/2/’ll/AUX/MD/aux/3 do/3/do/VERB/VB/ccomp/7 that/4/that/PRON/DT/dobj/3 then/5/then/ADV/RB/advmod/7 he/6/he/PRON/PRP/nsubj/7 started/7/start/VERB/VBD/ROOT/7 hopping/8/hop/VERB/VBG/xcomp/7 along/9/along/ADP/IN/prep/8 he/10/he/PRON/PRP/nsubj/11 crossed/11/cross/VERB/VBD/ccomp/7 there/12/there/ADV/RB/advmod/11 on/13/on/ADP/IN/prep/11 that/14/that/DET/DT/det/15 bridge/15/bridge/NOUN/NN/pobj/13')
# jeha1242 0 ('jaʔokeh', 'ready/0/ready/ADJ/JJ/ROOT/0')
# jeha1242 500 ('kalɔw yɛʔ hapaʔ haden yɛʔ kəbis', "if/0/if/SCONJ/IN/mark/2 I/1/I/PRON/PRP/nsubj/2 die/2/die/VERB/VBP/advcl/6 tomorrow/3/tomorrow/NOUN/NN/npadvmod/2 I/4/I/PRON/PRP/nsubj/6 'll/5/will/AUX/MD/aux/6 be/6/be/AUX/VB/ROOT/6 dead/7/dead/ADJ/JJ/acomp/6")
# jeha1242 1000 ('ʔoʔ t¤h', 'this/0/this/DET/DT/det/1 one/1/one/NOUN/NN/ROOT/1')
# jeju1234 0 ('aniuta məkəsʰuta', 'No/0/no/INTJ/UH/intj/3 thanks/1/thank/NOUN/NNS/intj/3 I/2/I/PRON/PRP/nsubj/3 ate/3/eat/VERB/VBD/ROOT/3 already/4/already/ADV/RB/advmod/3')
# jeju1234 500 ('ŧo', 'And/0/and/CCONJ/CC/ROOT/0')
# jeju1234 1000 ('əməŋ ţɕəţɕ məkɨnɨn kə iţɕen ŧɛə ţɕimɨn iţɕen ţɕaŋe kaŋ mak pʰola nasʰţɕuke', "once/0/once/SCONJ/IN/mark/3 they/1/they/PRON/PRP/nsubj/3 've/2/have/AUX/VBP/aux/3 got/3/get/VERB/VBN/ROOT/3 off/4/off/ADP/RP/prt/3 they/5/they/PRON/PRP$/poss/6 mother/6/mother/NOUN/NN/poss/8 's/7/'s/PART/POS/case/6 teats/8/teat/NOUN/NNS/dobj/3 you/9/you/PRON/PRP/nsubj/11 would/10/would/AUX/MD/aux/11 sell/11/sell/VERB/VB/relcl/8 them/12/they/PRON/PRP/dobj/11 on/13/on/ADP/IN/prep/11 the/14/the/DET/DT/det/15 market/15/market/NOUN/NN/pobj/13 you/16/you/PRON/PRP/nsubj/17 know/17/know/VERB/VBP/parataxis/3")
# jeju1234 1500 ('sʰatali hen olːa kan wan namue olːa kan wan', 'So/0/so/ADV/RB/advmod/2 he/1/he/PRON/PRP/nsubj/2 takes/2/take/VERB/VBZ/ROOT/2 a/3/a/DET/DT/det/4 ladder/4/ladder/NOUN/NN/dobj/2 goes/5/go/VERB/VBZ/ccomp/2 up/6/up/ADP/RP/prt/5 comes/7/come/VERB/VBZ/conj/2 back/8/back/ADV/RB/advmod/7 goes/9/go/VERB/VBZ/conj/2 up/10/up/ADP/RP/prt/9 on/11/on/ADP/IN/prep/9 the/12/the/DET/DT/det/13 tree/13/tree/NOUN/NN/pobj/11 comes/14/come/VERB/VBZ/conj/2 back/15/back/ADV/RB/advmod/14')
# kaka1265 0 ('bìlálè kŏndɛ tàna máa tèle', 'Bilale/0/Bilale/PROPN/NNP/compound/1 Konde/1/Konde/PROPN/NNP/npadvmod/3 how/2/how/SCONJ/WRB/advmod/3 are/3/be/AUX/VBP/ROOT/3 you/4/you/PRON/PRP/nsubj/3 how/5/how/SCONJ/WRB/advmod/7 has/6/have/AUX/VBZ/aux/7 been/7/be/AUX/VBN/ccomp/3 your/8/your/PRON/PRP$/poss/9 day/9/day/NOUN/NN/attr/7')
# kaka1265 500 ('ma le ma b a síkkɛla tún áwà', "That/0/that/PRON/DT/nsubj/1 's/1/be/AUX/VBZ/ROOT/1 what/2/what/PRON/WP/dobj/4 we/3/we/PRON/PRP/nsubj/4 think/4/think/VERB/VBP/ccomp/1")
# kaka1265 1000 ('kőnɔ ɓáyi mőgɔ mán tága kàawơkàn saa tėrenta i sęɛwanden i si i sìgi dúla sőtɔ', "When/0/when/SCONJ/WRB/advmod/3 a/1/a/DET/DT/det/2 person/2/person/NOUN/NN/nsubj/3 travels/3/travel/VERB/VBZ/advcl/12 all/4/all/ADV/RB/advmod/5 around/5/around/ADV/RB/advmod/3 if/6/if/SCONJ/IN/mark/8 you/7/you/PRON/PRP/nsubj/8 're/8/be/AUX/VBP/advcl/3 merry/9/merry/ADJ/JJ/acomp/8 you/10/you/PRON/PRP/nsubj/12 will/11/will/AUX/MD/aux/12 find/12/find/VERB/VB/ROOT/12 a/13/a/DET/DT/det/14 play/14/play/NOUN/NN/dobj/12 where/15/where/SCONJ/WRB/advmod/17 to/16/to/PART/TO/aux/17 stay/17/stay/VERB/VB/relcl/14")
# kaka1265 1500 ('áwà wo ni wo fàmmájigi álakɔ wo si gándalė sőtɔ kŏmin nà wo ni kęɛ kó an de tùgun kęɛnden kómin nà', 'So/0/so/ADV/RB/advmod/2 you/1/you/PRON/PRP/nsubj/2 apologize/2/apologize/VERB/VBP/ROOT/2 so/3/so/SCONJ/IN/mark/6 that/4/that/SCONJ/IN/mark/6 you/5/you/PRON/PRP/nsubj/6 receive/6/receive/VERB/VBP/advcl/2 education/7/education/NOUN/NN/dobj/6 gandal/8/gandal/ADJ/JJ/npadvmod/10 -/9/-/PUNCT/HYPH/punct/10 pular/10/pular/ADJ/JJ/amod/7 so/11/so/SCONJ/IN/mark/14 the/12/the/PRON/DT/pobj/11 you/13/you/PRON/PRP/nsubj/14 become/14/become/VERB/VBP/advcl/6 so/15/so/ADV/RB/advmod/14 as/16/as/SCONJ/IN/mark/19 they/17/they/PRON/PRP/nsubj/19 have/18/have/AUX/VBP/aux/19 become/19/become/VERB/VBN/advcl/14')
# kaka1265 2000 ('gárùnu fóo kálá bátáâ bő ì lá dùgéè tő', 'At/0/at/ADP/IN/ROOT/0 all/1/all/DET/PDT/predet/4 the/2/the/DET/DT/det/4 railway/3/railway/NOUN/NN/compound/4 stations/4/station/NOUN/NNS/pobj/0 everyone/5/everyone/PRON/NN/pobj/0 too/6/too/ADV/RB/advmod/7 it/7/it/PRON/PRP/appos/5 off/8/off/ADP/RP/advmod/5 in/9/in/ADP/IN/prep/5 his/10/his/PRON/PRP$/poss/11 country/11/country/NOUN/NN/pobj/9')
# kaka1265 2500 ('a máa màɲíninkarè kęɛ wo là ę bínta kőnɔ i le', "She/0/she/PRON/PRP/nsubj/3 did/1/do/AUX/VBD/aux/3 n't/2/not/PART/RB/neg/3 ask/3/ask/VERB/VB/ROOT/3 him/4/he/PRON/PRP/dative/3 E/5/E/PROPN/NNP/compound/6 Binta/6/Binta/PROPN/NNP/dobj/3 but/7/but/CCONJ/CC/cc/3 you/8/you/PRON/PRP/nsubj/9 are/9/be/AUX/VBP/conj/3")
# kaka1265 3000 ('dóon n a lakòo k a lanámaya', 'There/0/there/PRON/EX/expl/1 are/1/be/VERB/VBP/ROOT/1 some/2/some/PRON/DT/attr/1 who/3/who/PRON/WP/nsubj/4 wash/4/wash/VERB/VBP/relcl/2 it/5/it/PRON/PRP/dobj/4 and/6/and/CCONJ/CC/cc/4 make/7/make/VERB/VB/conj/4 it/8/it/PRON/PRP/nsubj/9 sleek/9/sleek/VERB/VB/ccomp/7')
# kaka1265 3500 ('a tée nŏn lŏn háa a máni kóè mán bòyi lúɲė mín ma le', "It/0/it/PRON/PRP/nsubj/1 's/1/be/AUX/VBZ/ROOT/1 impossible/2/impossible/ADJ/JJ/acomp/1 to/3/to/PART/TO/aux/4 know/4/know/VERB/VB/xcomp/1 on/5/on/ADP/IN/prep/4 what/6/what/DET/WDT/det/7 day/7/day/NOUN/NN/pcomp/5 the/8/the/DET/DT/det/9 thing/9/thing/NOUN/NN/nsubj/11 would/10/would/AUX/MD/aux/11 happen/11/happen/VERB/VB/ccomp/1")
# kaka1265 4000 ('őŏ pęrminansè őŏ', 'no/0/no/INTJ/UH/intj/3 the/1/the/DET/DT/det/3 village/2/village/NOUN/NN/compound/3 club/3/club/NOUN/NN/ROOT/3')
# kaka1265 4500 ('i ni dėɛmarè tára kà i dėɛman lŏgė labòyila', 'You/0/you/PRON/PRP/nsubj/1 ask/1/ask/VERB/VBP/ROOT/1 your/2/your/PRON/PRP$/poss/3 helpers/3/helper/NOUN/NNS/dobj/1 to/4/to/PART/TO/aux/5 help/5/help/VERB/VB/xcomp/1 you/6/you/PRON/PRP/nsubj/8 to/7/to/PART/TO/aux/8 fell/8/fell/VERB/VB/ccomp/5 the/9/the/DET/DT/det/10 trees/10/tree/NOUN/NNS/dobj/8')
# kama1351 0 ('klavdia plotnikova kolmas lint', 'Klavdia/0/Klavdia/PROPN/NNP/nmod/1 Plotnikova/1/Plotnikova/PROPN/NNP/nmod/3 third/2/third/ADJ/JJ/amod/3 tape/3/tape/NOUN/NN/ROOT/3')
# kama1351 500 ('dĭgəttə nʔergöleʔ šobi šuj süjö', 'Then/0/then/ADV/RB/advmod/3 a/1/a/DET/DT/det/2 bird/2/bird/NOUN/NN/nsubj/3 came/3/came/AUX/VBD/aux/4 flying/4/fly/VERB/VBG/ROOT/4')
# kama1351 1000 ('dĭgəttə aspaʔ dĭbər amnaʔbə', 'Then/0/then/ADV/RB/advmod/4 the/1/the/DET/DT/det/2 cauldron/2/cauldron/NOUN/NN/nsubj/4 is/3/be/AUX/VBZ/aux/4 sitting/4/sit/VERB/VBG/ROOT/4 there/5/there/ADV/RB/advmod/4')
# kama1351 1500 ('dĭ dĭʔnə bü deʔpiʔi', 'They/0/they/PRON/PRP/nsubj/1 brought/1/bring/VERB/VBD/ROOT/1 her/2/her/PRON/PRP$/poss/3 water/3/water/NOUN/NN/dobj/1')
# kama1351 2000 ('măn elem tăn molə molam', 'I/0/I/PRON/PRP/nsubj/2 will/1/will/AUX/MD/aux/2 become/2/become/VERB/VB/ROOT/2 your/3/your/PRON/PRP$/poss/4 friend/4/friend/NOUN/NN/attr/2')
# kama1351 2500 ('gibərdə ej alləm lučše kulambiam', "I/0/I/PRON/PRP/nsubj/3 wo/1/will/AUX/MD/aux/3 n't/2/not/PART/RB/neg/3 go/3/go/VERB/VB/ccomp/8 anywhere/4/anywhere/ADV/RB/advmod/3 I/5/I/PRON/PRP/nsubj/8 'd/6/would/AUX/MD/aux/8 rather/7/rather/ADV/RB/advmod/8 die/8/die/VERB/VB/ROOT/8")
# kama1351 3000 ('dĭn amnolaʔbə i bar ĭmbi ige amzittə', 'There/0/there/ADV/RB/advmod/3 they/1/they/PRON/PRP/nsubj/3 are/2/be/AUX/VBP/aux/3 living/3/live/VERB/VBG/ROOT/3 they/4/they/PRON/PRP/nsubj/5 have/5/have/VERB/VBP/ccomp/3 everything/6/everything/PRON/NN/dobj/5 to/7/to/PART/TO/aux/8 eat/8/eat/VERB/VB/relcl/6')
# kama1351 3500 ('dĭ bar kunolluʔpi', 'She/0/she/PRON/PRP/nsubj/1 fell/1/fall/VERB/VBD/ROOT/1 asleep/2/asleep/ADJ/JJ/acomp/1')
# kama1351 4000 ('dĭzen bar jaʔtarlaʔ mĭmbiʔi ara bĭʔpiʔi', 'They/0/they/PRON/PRP/nsubj/2 were/1/be/AUX/VBD/aux/2 going/2/go/VERB/VBG/ROOT/2 to/3/to/PART/TO/prep/2 visits/4/visit/NOUN/NNS/pobj/3 drank/5/drank/VERB/VB/advcl/2 vodka/6/vodka/NOUN/NN/dobj/5')
# kama1351 4500 ('măjagən', 'On/0/on/ADP/IN/ROOT/0 a/1/a/DET/DT/det/2 mountain/2/mountain/NOUN/NN/pobj/0 …/3/…/PUNCT/NFP/punct/0')
# kama1351 5000 ('üjüt naga i udat naga', 'No/0/no/DET/DT/det/1 legs/1/leg/NOUN/NNS/nsubj/3 no/2/no/DET/DT/det/3 arms/3/arm/NOUN/NNS/ROOT/3')
# kama1351 5500 ('üjüt uje udat naga a kudajdə üzlie', 'No/0/no/DET/DT/det/1 legs/1/leg/NOUN/NNS/ROOT/1 no/2/no/DET/DT/det/3 arms/3/arm/NOUN/NNS/dobj/1 but/4/but/CCONJ/CC/cc/6 it/5/it/PRON/PRP/nsubj/6 prays/6/pray/VERB/VBZ/ROOT/6 to/7/to/ADP/IN/prep/6 God/8/God/PROPN/NNP/pobj/7')
# kama1351 6000 ('dʔübige bü naga na măna kereʔ', 'There/0/there/PRON/EX/expl/1 is/1/be/VERB/VBZ/ccomp/6 no/2/no/DET/DT/det/4 warm/3/warm/ADJ/JJ/amod/4 water/4/water/NOUN/NN/attr/1 I/5/I/PRON/PRP/nsubj/6 need/6/need/VERB/VBP/ROOT/6')
# kama1351 6500 ('ej mĭlie', "He/0/he/PRON/PRP/nsubj/4 does/1/do/AUX/VBZ/aux/4 n't/2/not/PART/RB/neg/4 [/3/[/X/XX/dep/4 want/4/want/VERB/VB/ROOT/4 to/5/to/PART/TO/aux/7 ]/6/]/PUNCT/-RRB-/punct/7 give/7/give/VERB/VB/xcomp/4 [/8/[/X/XX/dobj/7 it/9/it/PRON/PRP/dobj/7 ]/10/]/X/XX/punct/7 away/11/away/ADV/RB/advmod/7")
# kama1351 7000 ('bʔeʔ nagur kö ibi dĭʔnə', 'She/0/she/PRON/PRP/nsubj/1 was/1/be/AUX/VBD/ROOT/1 thirteen/2/thirteen/NUM/CD/nummod/3 years/3/year/NOUN/NNS/npadvmod/4 old/4/old/ADJ/JJ/acomp/1')
# kama1351 7500 ('tăn d dʔijenə ej mumbiel', "Did/0/do/AUX/VBD/aux/3 n't/1/not/PART/RB/neg/3 you/2/you/PRON/PRP/nsubj/3 go/3/go/VERB/VB/ROOT/3 to/4/to/ADP/IN/prep/3 the/5/the/DET/DT/det/6 forest/6/forest/NOUN/NN/pobj/4")
# kama1351 8000 ('măn šonəgam i nereluʔpiem bar', "I/0/I/PRON/PRP/nsubj/2 'm/1/be/AUX/VBP/aux/2 going/2/go/VERB/VBG/ROOT/2 and/3/and/CCONJ/CC/cc/2 was/4/be/AUX/VBD/conj/2 scared/5/scared/ADJ/JJ/acomp/4")
# kama1351 8500 ('dĭgəttə inet nuʔməluʔpi', 'Then/0/then/ADV/RB/advmod/3 his/1/his/PRON/PRP$/poss/2 horse/2/horse/NOUN/NN/nsubj/3 ran/3/run/VERB/VBD/ROOT/3 [/4/[/X/XX/dep/3 away/5/away/ADV/RB/advmod/3 ]/6/]/PUNCT/-RRB-/punct/3')
# kama1351 9000 ('dʔibige büʔi büzʔiʔ abiʔi', 'They/0/they/PRON/PRP/nsubj/1 made/1/make/VERB/VBD/ROOT/1 them/2/they/PRON/PRP/dobj/1 with/3/with/ADP/IN/prep/1 warm/4/warm/ADJ/JJ/amod/5 water/5/water/NOUN/NN/pobj/3')
# kark1256 0 ('ʷu', 'I/0/I/PRON/PRP/ROOT/0')
# kark1256 500 ('ʃarbɛ ʃarɪ ʃarɪ wa waŋŋʊnaditʊ', 'he/0/he/PRON/PRP/nsubj/2 would/1/would/AUX/MD/aux/2 take/2/take/VERB/VB/ROOT/2 all/3/all/DET/PDT/predet/5 the/4/the/DET/DT/det/5 things/5/thing/NOUN/NNS/dobj/2 away/6/away/ADV/RB/advmod/2 from/7/from/ADP/IN/prep/6 him/8/he/PRON/PRP/pobj/7')
# kark1256 1000 ('wɪɪ titu', 'you/0/you/PRON/PRP/nsubj/2 would/1/would/AUX/MD/aux/2 give/2/give/VERB/VB/ROOT/2 them/3/they/PRON/PRP/dative/2 sorghum/4/sorghum/NOUN/NN/dobj/2')
# kark1256 1500 ('d̪ʊ́lʊ́ɲɪ́ ʃɛɛn', 'there/0/there/PRON/EX/expl/1 are/1/be/VERB/VBP/ROOT/1 granaries/2/granary/NOUN/NNS/attr/1')
# komn1238 0 ('nzone yəf rä', 'My/0/my/PRON/PRP$/poss/1 name/1/name/NOUN/NN/nsubj/2 is/2/be/AUX/VBZ/ROOT/2')
# komn1238 500 ('nä kayʔə', 'one/0/one/NUM/CD/nummod/1 day/1/day/NOUN/NN/ROOT/1')
# komn1238 1000 ('kwayʔanmäre', 'without/0/without/ADP/IN/ROOT/0 light/1/light/NOUN/NN/pobj/0')
# komn1238 1500 ('wati wəfərthərəth', 'they/0/they/PRON/PRP/nsubj/1 bit/1/bite/VERB/VBD/ROOT/1 it/2/it/PRON/PRP/dobj/1')
# komn1238 2000 ('boba wazi', 'to/0/to/ADP/IN/ROOT/0 the/1/the/DET/DT/det/3 other/2/other/ADJ/JJ/amod/3 side/3/side/NOUN/NN/pobj/0')
# komn1238 2500 ('fi təfrisamen swamnzərəm', 'lived/0/live/VERB/VBD/ROOT/0 in/1/in/ADP/IN/prep/0 Téférisam/2/Téférisam/PROPN/NNP/pobj/1')
# komn1238 3000 ('we ʔanewä samäyofake', 'we/0/we/PRON/PRP/nsubj/1 repeated/1/repeat/VERB/VBD/ROOT/1 the/2/the/DET/DT/det/3 work/3/work/NOUN/NN/dobj/1 on/4/on/ADP/IN/prep/1 the/5/the/DET/DT/det/7 same/6/same/ADJ/JJ/amod/7 sago/7/sago/NOUN/NN/pobj/4')
# komn1238 3500 ('bäneme zrarärəth nzürime ʔe kräbəth', 'we/0/we/PRON/PRP/nsubj/1 apply/1/apply/VERB/VBP/ROOT/1 the/2/the/DET/DT/det/4 nzüri/3/nzüri/ADJ/JJ/amod/4 tree/4/tree/NOUN/NN/dobj/1 until/5/until/SCONJ/IN/mark/8 it/6/it/PRON/PRP/nsubjpass/8 is/7/be/AUX/VBZ/auxpass/8 finished/8/finish/VERB/VBN/advcl/1')
# komn1238 4000 ('wati', 'then/0/then/ADV/RB/ROOT/0')
# komn1238 4500 ('watik', 'okay/0/okay/INTJ/UH/ROOT/0')
# komn1238 5000 ('ʔerna bäne ʔerna', 'while/0/while/SCONJ/IN/mark/2 they/1/they/PRON/PRP/nsubj/2 were/2/be/AUX/VBD/ROOT/2 there/3/there/ADV/RB/advmod/2')
# komn1238 5500 ('ŋatha zə', 'did/0/do/VERB/VBD/ROOT/0 the/1/the/DET/DT/det/2 dog/2/dog/NOUN/NN/nsubj/0')
# komn1238 6000 ('sräzinəth', 'they/0/they/PRON/PRP/nsubj/1 put/1/put/VERB/VBD/ROOT/1 him/2/he/PRON/PRP/dobj/1 down/3/down/ADP/RP/prt/1')
# komn1238 6500 ('watik', 'okay/0/okay/INTJ/UH/ROOT/0')
# komn1238 7000 ('zena watik ʔane bəthan fof wiyak', 'today/0/today/NOUN/NN/npadvmod/4 the/1/the/DET/DT/det/2 magic/2/magic/NOUN/NN/nsubj/4 is/3/be/AUX/VBZ/aux/4 going/4/go/VERB/VBG/ROOT/4 around/5/around/ADV/RB/advmod/4')
# komn1238 7500 ('ʔahə', 'ah/0/ah/INTJ/UH/ROOT/0')
# ligh1234 0 ('karntapawu im siting jarntukurl', 'a/0/a/DET/DT/det/2 little/1/little/ADJ/JJ/amod/2 girl/2/girl/NOUN/NN/nsubj/4 was/3/be/AUX/VBD/aux/4 siting/4/site/VERB/VBG/ROOT/4 with/5/with/ADP/IN/prep/4 a/6/a/DET/DT/det/7 dog/7/dog/NOUN/NN/pobj/5')
# ligh1234 500 ('jintakari kurdupawu im sidan im sidan', 'another/0/another/DET/DT/det/1 child/1/child/NOUN/NN/nsubj/2 sat/2/sit/VERB/VBD/ROOT/2 down/3/down/ADP/RP/prt/2 xxx/4/xxx/PROPN/NNP/npadvmod/2 sat/5/sit/VERB/VBD/conj/2 down/6/down/ADP/RP/prt/5')
# ligh1234 1000 ('an dem ave aksident na', 'and/0/and/CCONJ/CC/cc/3 then/1/then/ADV/RB/advmod/3 they/2/they/PRON/PRP/nsubj/3 had/3/have/VERB/VBD/ROOT/3 an/4/an/DET/DT/det/5 accident/5/accident/NOUN/NN/dobj/3')
# ngal1292 0 ('keninjbike warlang', 'This/0/this/DET/DT/det/3 whatsit/1/whatsit/NOUN/NN/amod/3 orange/2/orange/ADJ/JJ/amod/3 bat/3/bat/NOUN/NN/ROOT/3')
# ngal1292 500 ('kardu kahyinhyininj', 'he/0/he/PRON/PRP/nsubj/2 was/1/be/AUX/VBD/aux/2 thinking/2/think/VERB/VBG/ROOT/2 maybe/3/maybe/ADV/RB/advmod/2')
# ngal1292 1000 ('kenhbinokah', 'in/0/in/ADP/IN/ROOT/0 his/1/his/PRON/PRP$/poss/2 whatsit/2/whatsit/NOUN/NN/pobj/0')
# ngal1292 1500 ('merlkminj', 'shinning/0/shin/VERB/VBG/ROOT/0')
# nngg1234 0 ('gǁain cuinya a nǀaa nǁang', 'hyena/0/hyena/PROPN/NNP/nsubj/1 sits/1/sit/VERB/VBZ/ROOT/1 and/2/and/CCONJ/CC/cc/1 watches/3/watch/VERB/VBZ/conj/1 the/4/the/DET/DT/det/5 house/5/house/NOUN/NN/dobj/3')
# nngg1234 500 ('si ke si ke gǀunuke', 'this/0/this/PRON/DT/nsubj/1 is/1/be/AUX/VBZ/ROOT/1 us/2/we/PRON/PRP/attr/1 this/3/this/PRON/DT/nsubj/4 is/4/be/AUX/VBZ/ccomp/1 us/5/we/PRON/PRP/attr/4 indeed/6/indeed/ADV/RB/advmod/4')
# nngg1234 1000 ('ons is boesmans', 'we/0/we/PRON/PRP/nsubj/1 are/1/be/AUX/VBP/ROOT/1 Bushmen/2/bushman/NOUN/NNS/attr/1')
# nngg1234 1500 ('hey', 'hey/0/hey/INTJ/UH/ROOT/0')
# nngg1234 2000 ('lalie se ʘoaxe', "it/0/it/PRON/PRP/nsubj/1 is/1/be/AUX/VBZ/ROOT/1 Lalie/2/Lalie/PROPN/NNP/poss/4 's/3/'s/PART/POS/case/2 daugher/4/daugher/NOUN/NN/attr/1")
# nngg1234 2500 ('ǁhoen ǂoo kua ha ǁʼae ng ǀai nǁaa', 'the/0/the/DET/DT/det/2 old/1/old/ADJ/JJ/amod/2 man/2/man/NOUN/NN/nsubj/3 says/3/say/VERB/VBZ/ROOT/3 he/4/he/PRON/PRP/nsubj/5 goes/5/go/VERB/VBZ/ccomp/3 and/6/and/CCONJ/CC/cc/5 fetches/7/fetch/VERB/VBZ/conj/5 her/8/she/PRON/PRP/dobj/7')
# nngg1234 3000 ('a ku xainki ǃauke ng ǀaqasi ha ku siia sii i ǁʼae nǁang', 'he/0/he/PRON/PRP/nsubj/1 becomes/1/become/VERB/VBZ/ROOT/1 scared/2/scared/ADJ/JJ/acomp/1 of/3/of/ADP/IN/prep/2 the/4/the/DET/DT/det/5 snake/5/snake/NOUN/NN/pobj/3 she/6/she/PRON/PRP/nsubj/7 says/7/say/VERB/VBZ/relcl/5 come/8/come/VERB/VB/dep/1 come/9/come/VERB/VB/acomp/8 we/10/we/PRON/PRP/nsubj/11 go/11/go/VERB/VBP/ccomp/1 home/12/home/ADV/RB/advmod/11')
# nngg1234 3500 ('na ka ng ǂau ki', 'I/0/I/PRON/PRP/nsubj/2 will/1/will/AUX/MD/aux/2 crush/2/crush/VERB/VB/ROOT/2 them/3/they/PRON/PRP/dobj/2')
# nngg1234 4000 ('ǁu katyumʼin ǀqxʼabaǂʼaoke', 'and/0/and/CCONJ/CC/cc/5 you/1/you/PRON/PRP/nsubj/5 also/2/also/ADV/RB/advmod/5 must/3/must/AUX/MD/aux/5 not/4/not/PART/RB/neg/5 listen/5/listen/VERB/VB/ROOT/5 to/6/to/ADP/IN/prep/5 the/7/the/DET/DT/det/8 police/8/police/NOUN/NN/pobj/6')
# nngg1234 4500 ('ǃxaeka ʼai', 'tomorrow/0/tomorrow/NOUN/NN/punct/2 :/1/:/PUNCT/:/punct/0 ai/2/ai/VERB/VB/ROOT/2')
# nngg1234 5000 ('gǂausi', 'tsamma/0/tsamma/ADV/RB/ROOT/0')
# nngg1234 5500 ('nǁaang', 'nǁng/0/nǁng/PROPN/NNP/ROOT/0')
# pnar1238 0 ('tæ ong u khana yeithaw chong thaw sah phi', "`/0/`/PUNCT/``/punct/3 so/1/so/ADV/RB/advmod/3 he/2/he/PRON/PRP/nsubj/3 said/3/say/VERB/VBD/ROOT/3 say/4/say/VERB/VB/intj/3 #/5/#/SYM/SYM/punct/3 tell/6/tell/VERB/VB/xcomp/3 us/7/we/PRON/PRP/dative/6 your/8/your/PRON/PRP$/poss/9 place/9/place/NOUN/NN/dobj/6 where/10/where/SCONJ/WRB/advmod/12 you/11/you/PRON/PRP/nsubj/12 live/12/live/VERB/VBP/relcl/9 ./13/./PUNCT/./punct/3 '/14/'/PUNCT/''/punct/3")
# pnar1238 500 ('kisnæm e uong boi kisnæm sanphaw le sanphaw soo kitu kisnæm jan dæ snæm ynru thain tæ da ræp o', "`/0/`/PUNCT/``/punct/2 I/1/I/PRON/PRP/nsubj/2 think/2/think/VERB/VBP/ROOT/2 its/3/its/PRON/PRP$/ccomp/2 in/4/in/ADP/IN/prep/3 the/5/the/DET/DT/det/6 year/6/year/NOUN/NN/pobj/4 53/7/53/NUM/CD/npadvmod/2 -/8/-/SYM/SYM/punct/9 54/9/54/NUM/CD/prep/7 near/10/near/ADP/IN/prep/7 there/11/there/ADV/RB/pcomp/10 in/12/in/ADP/IN/prep/7 1960/13/1960/NUM/CD/pobj/12 i/14/I/PRON/PRP/nsubj/17 was/15/be/AUX/VBD/aux/17 already/16/already/ADV/RB/advmod/17 doing/17/do/VERB/VBG/ccomp/2 agriculture/18/agriculture/NOUN/NN/dobj/17 ./19/./PUNCT/./punct/2 '/20/'/PUNCT/''/punct/2 '/21/'/PUNCT/''/punct/2")
# ruul1235 0 ('amaβara gaːŋge niːɲɟe nalumu aida ntakimaɲi', 'My/0/my/PRON/PRP$/poss/1 name/1/name/NOUN/NN/nsubj/2 is/2/be/AUX/VBZ/ROOT/2 Nalumu/3/Nalumu/PROPN/NNP/compound/4 Aidah/4/Aidah/PROPN/NNP/compound/6 Ntakimanyi/5/Ntakimanyi/PROPN/NNP/compound/6 Lit/6/Lit/PROPN/NNP/attr/2 My/7/my/PRON/PRP$/poss/8 names/8/name/NOUN/NNS/nsubj/9 are/9/be/AUX/VBP/conj/2')
# ruul1235 500 ('okwoːŋgera', 'To/0/to/PART/TO/aux/1 add/1/add/VERB/VB/ROOT/1 …/2/…/PUNCT/NFP/punct/1')
# ruul1235 1000 ('omuːntu ejaɲeːnteire oku ɲaːɲɟa', 'Someone/0/someone/PRON/NN/ROOT/0 who/1/who/PRON/WP/nsubj/2 grew/2/grow/VERB/VBD/relcl/0 to/3/to/ADP/IN/prep/2 adolescence/4/adolescence/NOUN/NN/pobj/3 on/5/on/ADP/IN/prep/2 the/6/the/DET/DT/det/7 lake/7/lake/NOUN/NN/pobj/5')
# ruul1235 1500 ('aβakaire omukaːgiri arijo', 'Aah/0/aah/VERB/VB/dep/5 the/1/the/DET/DT/det/2 parents/2/parent/NOUN/NNS/dobj/0 …/3/…/PUNCT/NFP/punct/5 Mukaagiri/4/Mukaagiri/PROPN/NNP/nsubj/5 is/5/be/AUX/VBZ/ROOT/5 fine/6/fine/ADJ/JJ/acomp/5 [/7/[/X/XX/dep/11 Note/8/note/NOUN/NN/dep/11 :/9/:/PUNCT/:/punct/11 Mukaagiri/10/Mukaagiri/PROPN/NNP/nsubj/11 is/11/be/AUX/VBZ/ROOT/11 a/12/a/DET/DT/det/14 clan/13/clan/NOUN/NN/compound/14 title/14/title/NOUN/NN/attr/11 ./15/./PUNCT/./punct/11 ]/16/]/PUNCT/-RRB-/punct/11')
# ruul1235 2000 ('atiβuni oni aliːŋgirja omu sowani zaβaːndi', "Now/0/now/INTJ/UH/intj/2 this/1/this/DET/DT/det/2 one/2/one/NOUN/NN/ROOT/2 who/3/who/PRON/WP/nsubj/4 peeps/4/peep/VERB/VBZ/relcl/2 in/5/in/ADP/IN/prep/4 other/6/other/ADJ/JJ/amod/7 people/7/people/NOUN/NNS/poss/9 's/8/'s/PART/POS/case/7 plates/9/plate/NOUN/NNS/pobj/5")
# ruul1235 2500 ('βakoβa kasita otegeːre eβiːntu eβisatu', 'they/0/they/PRON/PRP/nsubj/1 say/1/say/VERB/VBP/ROOT/1 that/2/that/SCONJ/IN/mark/6 in/3/in/ADP/IN/prep/6 case/4/case/NOUN/NN/pobj/3 you/5/you/PRON/PRP/nsubj/6 understand/6/understand/VERB/VBP/ccomp/1 the/7/the/DET/DT/det/8 things/8/thing/NOUN/NNS/dobj/6')
# sadu1234 0 ('nu wua tse texɚ nu ʑo', 'Well/0/well/INTJ/UH/intj/1 let/1/let/VERB/VB/ROOT/1 me/2/I/PRON/PRP/nsubj/4 now/3/now/ADV/RB/advmod/4 tell/4/tell/VERB/VB/ccomp/1 you/5/you/PRON/PRP/dobj/4 again/6/again/ADV/RB/advmod/4')
# sadu1234 500 ('a tɕiphe tsua ɡɯ lɛ', 'Ah/0/ah/INTJ/UH/intj/3 money/1/money/NOUN/NN/nsubjpass/3 is/2/be/AUX/VBZ/auxpass/3 made/3/make/VERB/VBN/ROOT/3 from/4/from/ADP/IN/prep/3 business/5/business/NOUN/NN/pobj/4')
# sadu1234 1000 ('suapan ljɔ tɕo ŋonɛ', 'with/0/with/ADP/IN/ROOT/0 a/1/a/DET/DT/det/3 full/2/full/ADJ/JJ/amod/3 gallop/3/gallop/NOUN/NN/pobj/0')
# sanz1248 0 ('ккара дус ккара дус рихубледе нехъ баркьиб гьелилагьетте нехъбаркьиблагьетти агурда келгунда', 'I/0/I/PRON/PRP/nsubj/1 was/1/be/AUX/VBD/ROOT/1 18/2/18/NUM/CD/attr/1 We/3/we/PRON/PRP/nsubj/4 got/4/get/VERB/VBD/ROOT/4 married/5/marry/VERB/VBN/acomp/4 and/6/and/CCONJ/CC/cc/5 after/7/after/ADP/IN/conj/5 the/8/the/DET/DT/det/9 wedding/9/wedding/NOUN/NN/pobj/7 I/10/I/PRON/PRP/nsubj/11 worked/11/work/VERB/VBD/relcl/9 as/12/as/ADP/IN/prep/11 a/13/a/DET/DT/det/14 milkmaid/14/milkmaid/NOUN/NN/pobj/12 in/15/in/ADP/IN/prep/14 Tsaaldarki/16/Tsaaldarki/PROPN/NNP/pobj/15')
# savo1255 0 ('kapistu toneo', 'Kapisitu/0/kapisitu/ADJ/JJ/amod/1 toneo/1/toneo/NOUN/NNS/ROOT/1')
# savo1255 500 ('telo lo la lali lavelighu savulia telo tivali telo lo tugha toa kadali tivali', 'Then/0/then/ADV/RB/advmod/2 he/1/he/PRON/PRP/nsubj/2 said/2/say/VERB/VBD/ROOT/2 he/3/he/PRON/PRP/nsubj/5 would/4/would/AUX/MD/aux/5 kill/5/kill/VERB/VB/ccomp/2 him/6/he/PRON/PRP/dobj/5 because/7/because/SCONJ/IN/prep/5 of/8/of/ADP/IN/pcomp/7 that/9/that/PRON/DT/pobj/7 and/10/and/CCONJ/CC/cc/2 he/11/he/PRON/PRP/nsubj/12 chased/12/chase/VERB/VBD/conj/2 him/13/he/PRON/PRP/dobj/12 away/14/away/ADV/RB/advmod/12 the/15/the/DET/DT/det/17 very/16/very/ADV/RB/amod/17 replacement/17/replacement/NOUN/NN/nsubj/18 chased/18/chase/VERB/VBD/ccomp/12 him/19/he/PRON/PRP/dobj/18 away/20/away/ADV/RB/advmod/18')
# sout2856 0 ('itili nag tiawi iskei itok kaipiatlak teesa nanwei iskei nega go nmatu nega', 'He/0/he/PRON/PRP/nsubj/1 told/1/tell/VERB/VBD/ROOT/1 that/2/that/SCONJ/IN/mark/4 there/3/there/PRON/EX/expl/4 was/4/be/VERB/VBD/ccomp/1 this/5/this/DET/DT/det/6 ancestor/6/ancestor/NOUN/NN/attr/4 who/7/who/PRON/WP/nsubj/8 had/8/have/VERB/VBD/relcl/6 a/9/a/DET/DT/det/10 son/10/son/NOUN/NN/dobj/8 he/11/he/PRON/PRP/appos/10 and/12/and/CCONJ/CC/cc/11 his/13/his/PRON/PRP$/poss/14 wife/14/wife/NOUN/NN/dobj/1')
# sout2856 500 ('ina ipa na ikalki nkal ga inom me imailum pnaklu kom ni taaƥes ipaskin nƥaun', "He/0/he/PRON/PRP/nsubj/1 wanted/1/want/VERB/VBD/ROOT/1 to/2/to/PART/TO/aux/3 go/3/go/VERB/VB/xcomp/1 to/4/to/AUX/IN/aux/5 dress/5/dress/VERB/VB/advcl/3 in/6/in/ADP/IN/prep/5 his/7/his/PRON/PRP$/poss/8 clothes/8/clothe/NOUN/NNS/pobj/6 Then/9/then/ADV/RB/advmod/13 he/10/he/PRON/PRP/nsubj/13 quietly/11/quietly/ADV/RB/advmod/13 completely/12/completely/ADV/RB/advmod/13 stole/13/steal/VERB/VBD/conj/1 the/14/the/DET/DT/det/15 swamphen/15/swamphen/PROPN/NNP/poss/17 's/16/'s/PART/POS/case/15 comb/17/comb/NOUN/NN/dobj/13 and/18/and/CCONJ/CC/cc/13 put/19/put/VERB/VBD/conj/13 it/20/it/PRON/PRP/dobj/19 on/21/on/ADP/IN/prep/19 his/22/his/PRON/PRP$/poss/23 head/23/head/NOUN/NN/pobj/21")
# sout2856 1000 ('ale kipestafi e me ag kutfale mai pak nfal faat nen maarik nen itok e¡rom faat nen kipestafi me ag kutfale mai go maarik nen kiga trausi kitli na komam mtulep ramai pak tal¡at me wak ƥur iskei iƥas komam', 'He/0/he/PRON/PRP/nsubj/1 said/1/say/VERB/VBD/ROOT/1 Hey/2/hey/INTJ/UH/intj/7 but/3/but/CCONJ/CC/cc/7 how/4/how/SCONJ/WRB/advmod/7 did/5/do/AUX/VBD/aux/7 you/6/you/PRON/PRP/nsubj/7 get/7/get/VERB/VB/ccomp/1 into/8/into/ADP/IN/prep/7 this/9/this/DET/DT/det/10 cave/10/cave/NOUN/NN/pobj/8 The/11/the/DET/DT/det/12 man/12/man/NOUN/NN/nsubj/18 who/13/who/PRON/WP/nsubj/14 was/14/be/AUX/VBD/relcl/12 inside/15/inside/ADP/IN/prep/14 the/16/the/DET/DT/det/17 cave/17/cave/NOUN/NN/pobj/15 said/18/say/VERB/VBD/conj/1 But/19/but/CCONJ/CC/cc/24 you/20/you/PRON/PRP/nsubj/24 how/21/how/SCONJ/WRB/advmod/24 did/22/do/AUX/VBD/aux/24 you/23/you/PRON/PRP/nsubj/24 come/24/come/VERB/VB/ROOT/24 here/25/here/ADV/RB/advmod/24 And/26/and/CCONJ/CC/cc/29 the/27/the/DET/DT/det/28 man/28/man/NOUN/NN/nsubj/29 spoke/29/speak/VERB/VBD/ROOT/29 he/30/he/PRON/PRP/nsubj/31 said/31/say/VERB/VBD/ccomp/29 We/32/we/PRON/PRP/dobj/31 my/33/my/PRON/PRP$/poss/34 wife/34/wife/NOUN/NN/appos/32 and/35/and/CCONJ/CC/cc/34 me/36/I/PRON/PRP/conj/34 we/37/we/PRON/PRP/nsubj/38 went/38/go/VERB/VBD/ccomp/31 to/39/to/ADP/IN/prep/38 our/40/our/PRON/PRP$/poss/41 garden/41/garden/NOUN/NN/pobj/39 but/42/but/CCONJ/CC/cc/29 a/43/a/DET/DT/det/45 big/44/big/ADJ/JJ/amod/45 pig/45/pig/NOUN/NN/nsubj/46 chased/46/chase/VERB/VBD/conj/29 us/47/we/PRON/PRP/dobj/46')
# sout2856 1500 ('nt to esu¡ to me ag kuweswes', 'At/0/at/ADP/IN/prep/5 home/1/home/NOUN/NN/pobj/0 but/2/but/CCONJ/CC/cc/0 did/3/do/AUX/VBD/aux/5 you/4/you/PRON/PRP/nsubj/5 work/5/work/VERB/VB/ROOT/5 in/6/in/ADP/IN/prep/5 1968/7/1968/NUM/CD/pobj/6')
# sumi1235 0 ('ningqoye', 'for/0/for/ADP/IN/ROOT/0 us/1/we/PRON/PRP/pobj/0')
# sumi1235 500 ('ikemu akchiqkepu', 'but/0/but/CCONJ/CC/cc/2 it/1/it/PRON/PRP/nsubj/2 was/2/be/AUX/VBD/ROOT/2 shocking/3/shocking/ADJ/JJ/acomp/2 then/4/then/ADV/RB/advmod/2')
# sumi1235 1000 ('pano kŭmsŭkeu ti pano kŭthŭ', 'he/0/he/PRON/PRP/nsubj/1 thought/1/think/VERB/VBD/ROOT/1 that/2/that/SCONJ/IN/ccomp/1 the/3/the/DET/DT/det/4 they/4/they/PRON/PRP/ccomp/1 three/5/three/NUM/CD/appos/4')
# sumi1235 1500 ('shi aklo qhivekechoi ipe mo puno ti', 'kept/0/keep/VERB/VBD/ROOT/0 it/1/it/PRON/PRP/dobj/0 at/2/at/ADP/IN/prep/0 home/3/home/NOUN/NN/pobj/2 and/4/and/CCONJ/CC/cc/0 like/5/like/ADP/IN/prep/9 this/6/this/PRON/DT/pobj/5 did/7/do/AUX/VBD/aux/9 not/8/not/PART/RB/neg/9 go/9/go/VERB/VB/conj/0 out/10/out/ADV/RB/prt/9 and/11/and/CCONJ/CC/cc/9 that/12/that/SCONJ/IN/conj/9')
# sumi1235 2000 ('tsŭngumiqono kohimalo', 'the/0/the/DET/DT/det/1 Angamis/1/Angamis/PROPN/NNP/ROOT/1 in/2/in/ADP/IN/prep/1 Kohima/3/Kohima/PROPN/NNP/pobj/2')
# svan1243 0 ('ašxun mišgouba nä mexanäyšs xweḳrawdad ečkas anqäd mišgo uba i latxwarte ačäd ḳoǯärte', '_/0/_/PUNCT/NFP/ROOT/0 Once/1/once/SCONJ/IN/mark/14 my/2/my/PRON/PRP$/poss/3 uncle/3/uncle/NOUN/NN/nsubj/14 when/4/when/SCONJ/WRB/advmod/6 we/5/we/PRON/PRP/nsubj/6 were/6/be/AUX/VBD/advcl/3 on/7/on/ADP/IN/prep/6 the/8/the/DET/DT/det/10 Mekhana/9/Mekhana/PROPN/NNP/compound/10 mountain/10/mountain/NOUN/NN/pobj/7 then/11/then/ADV/RB/advmod/14 my/12/my/PRON/PRP$/poss/13 uncle/13/uncle/NOUN/NN/nsubj/14 went/14/go/VERB/VBD/ROOT/14 off/15/off/ADP/RP/prt/14 to/16/to/PART/TO/aux/17 go/17/go/VERB/VB/advcl/14 hunting/18/hunt/VERB/VBG/dobj/17 in/19/in/ADP/IN/prep/18 the/20/the/DET/DT/det/21 rocks/21/rock/NOUN/NNS/pobj/19')
# svan1243 500 ('čûadsodgûmǟnx', 'They/0/they/PRON/PRP/nsubj/2 were/1/be/AUX/VBD/aux/2 camping/2/camp/VERB/VBG/ROOT/2 there/3/there/ADV/RB/advmod/2')
# svan1243 1000 ("ġûažar čûīsgroldax ž'īmzəraldax aminšû i amzɚrdax", 'Men/0/man/NOUN/NNS/nsubj/2 would/1/would/AUX/MD/aux/2 sit/2/sit/VERB/VB/ROOT/2 toast/3/toast/NOUN/NN/dobj/2 and/4/and/CCONJ/CC/cc/2 bless/5/bless/VERB/VB/conj/2')
# taba1259 0 ('qʔuˤr dustː axnu', 'There/0/there/PRON/EX/expl/1 were/1/be/VERB/VBD/ROOT/1 two/2/two/NUM/CD/nummod/3 friends/3/friend/NOUN/NNS/attr/1')
# taba1259 500 ('qaˤl afunuz', 'Are/0/be/AUX/VBP/ROOT/0 you/1/you/PRON/PRP/nsubj/0 angry/2/angry/ADJ/JJ/acomp/0')
# teop1238 0 ('peho vuri', 'Once/0/once/ADV/RB/ROOT/0 -/1/-/PUNCT/./punct/0')
# teop1238 500 ('ean sa paa tara haa vuru e taan ei evehe kaakoo maenei tea', 'You/0/you/PRON/PRP/nsubj/2 haven´t/1/haven´t/VERB/VBP/appos/0 seen/2/see/VERB/VBD/ROOT/2 anybody/3/anybody/PRON/NN/nsubj/4 walking/4/walk/VERB/VBG/ccomp/2 here/5/here/ADV/RB/advmod/4 to/6/to/ADP/IN/prep/2')
# teop1238 1000 ('meori paa nao vaha maa meori', 'And/0/and/CCONJ/CC/cc/2 they/1/they/PRON/PRP/nsubj/2 went/2/go/VERB/VBD/ROOT/2 and/3/and/CCONJ/CC/cc/2 they/4/they/PRON/PRP/punct/2')
# teop1238 1500 ('eve teo mandee kiu hiava', 'it/0/it/PRON/PRP/nsubj/1 is/1/be/AUX/VBZ/ROOT/1 on/2/on/ADP/IN/prep/1 Monday/3/Monday/PROPN/NNP/pobj/2 next/4/next/ADJ/JJ/amod/5 week/5/week/NOUN/NN/npadvmod/1')
# texi1237 0 ('entonse tum pääñ dyim iichaʔ chyumeeñ', 'So/0/so/ADV/RB/advmod/2 they/1/they/PRON/PRP/nsubj/2 say/2/say/VERB/VBP/ROOT/2 a/3/a/DET/DT/det/4 man/4/man/NOUN/NN/nsubj/5 has/5/have/VERB/VBZ/ccomp/2 money/6/money/NOUN/NN/dobj/5')
# texi1237 500 ('däk beʔetzäʔ ñyuuñeʔ', 'Go/0/go/VERB/VB/ROOT/0 get/1/get/VERB/VB/advcl/0 yourself/2/yourself/PRON/PRP/dative/1 a/3/a/DET/DT/det/4 wife/4/wife/NOUN/NN/dobj/1')
# texi1237 1000 ('iichaʔ chipshkuʔ byumbe', 'He/0/he/PRON/PRP/nsubj/1 had/1/have/VERB/VBD/ROOT/1 his/2/his/PRON/PRP$/poss/4 shooter/3/shooter/ADJ/JJ/amod/4 everything/4/everything/PRON/NN/dobj/1')
# texi1237 1500 ('yäʔäp jaa dyim', 'Today/0/today/NOUN/NN/ROOT/0')
# texi1237 2000 ('puuta ke wää dyim', "Puta/0/puta/VERB/VB/intj/6 that/1/that/PRON/DT/nsubj/2 's/2/be/AUX/VBZ/ccomp/0 good/3/good/ADJ/JJ/acomp/2 #/4/#/SPACE/_SP/dep/3 he/5/he/PRON/PRP/nsubj/6 says/6/say/VERB/VBZ/ROOT/6")
# texi1237 2500 ('njem maʔ tzäʔyam', 'There/0/there/ADV/RB/advmod/2 he/1/he/PRON/PRP/nsubj/2 is/2/be/AUX/VBZ/ROOT/2')
# trin1278 0 ('ejamikpo tatanoviono ejamikpo memenoviono', 'Hello/0/hello/INTJ/UH/ROOT/0 ladies/1/lady/NOUN/NNS/npadvmod/0 and/2/and/CCONJ/CC/cc/1 gentlemen/3/gentleman/NOUN/NNS/conj/1')
# trin1278 500 ('tarotopo wichʔo', 'Is/0/be/AUX/VBZ/ROOT/0 it/1/it/PRON/PRP/nsubj/0 enough/2/enough/ADJ/JJ/acomp/0 #/3/#/SPACE/_SP/dep/2 Not/4/not/PART/RB/neg/0 yet/5/yet/ADV/RB/advmod/0')
# trin1278 1000 ('ma ʔchane tkósukre to kutsi tachareʔo', 'The/0/the/DET/DT/det/1 man/1/man/NOUN/NN/nsubj/2 cultivates/2/cultivate/VERB/VBZ/ROOT/2 the/3/the/DET/DT/det/4 thrush/4/thrush/NOUN/NN/nsubj/5 pulls/5/pull/VERB/VBZ/ccomp/2 out/6/out/ADP/RP/prt/5')
# trin1278 1500 ('ma tkoyʔe to vaka tkoptiriko', 'The/0/the/DET/DT/det/1 one/1/one/NOUN/NN/ROOT/1 who/2/who/PRON/WP/nsubj/3 has/3/have/VERB/VBZ/relcl/1 cattle/4/cattle/NOUN/NNS/compound/5 milks/5/milk/NOUN/NNS/dobj/3')
# trin1278 2000 ('ñimichrukripuiji tamutu to nayeeruwyooʔi', 'he/0/he/PRON/PRP/nsubj/3 had/1/have/AUX/VBD/aux/3 already/2/already/ADV/RB/advmod/3 taken/3/take/VERB/VBN/ROOT/3 over/4/over/ADP/RP/prt/3 all/5/all/DET/PDT/predet/7 the/6/the/DET/DT/det/7 stuffs/7/stuff/NOUN/NNS/dobj/3')
# urum1249 0 ('bänä ğala gäldılär iki yuz el iräli trapezondadan', 'To/0/to/ADP/IN/prep/4 my/1/my/PRON/PRP$/poss/2 mind/2/mind/NOUN/NN/pobj/0 they/3/they/PRON/PRP/nsubj/4 came/4/come/VERB/VBD/ROOT/4 two/5/two/NUM/CD/compound/6 hundred/6/hundred/NUM/CD/nummod/7 years/7/year/NOUN/NNS/npadvmod/8 ago/8/ago/ADV/RB/advmod/4 from/9/from/ADP/IN/prep/4 Trabzon/10/Trabzon/PROPN/NNP/pobj/9')
# urum1249 500 ('mamam mamamda čoğ bülmer', 'Also/0/also/ADV/RB/advmod/5 my/1/my/PRON/PRP$/poss/2 mother/2/mother/NOUN/NN/nsubj/5 does/3/do/AUX/VBZ/aux/5 n’t/4/not/PART/RB/neg/5 speak/5/speak/VERB/VB/ROOT/5 well/6/well/ADV/RB/advmod/5')
# urum1249 1000 ('i belädä šei yazmahmazmah yohtur', 'And/0/and/CCONJ/CC/cc/2 it/1/it/PRON/PRP/nsubj/2 has/2/have/VERB/VBZ/ROOT/2 no/3/no/DET/DT/det/4 writing/4/writing/NOUN/NN/dobj/2')
# urum1249 1500 ('gäldılär boš erlärıdi ävlär yoğudi biše yoğudi', 'When/0/when/SCONJ/WRB/advmod/2 they/1/they/PRON/PRP/nsubj/2 got/2/get/VERB/VBD/advcl/5 here/3/here/ADV/RB/advmod/2 there/4/there/PRON/EX/expl/5 were/5/be/VERB/VBD/ROOT/5 no/6/no/DET/DT/det/7 houses/7/house/NOUN/NNS/attr/5 there/8/there/PRON/EX/expl/9 was/9/be/VERB/VBD/advcl/5 nothing/10/nothing/PRON/NN/attr/9 here/11/here/ADV/RB/advmod/9')
# urum1249 2000 ('ušahlarida üč ğızım oldi', 'And/0/and/CCONJ/CC/cc/2 I/1/I/PRON/PRP/nsubj/2 have/2/have/VERB/VBP/ROOT/2 three/3/three/NUM/CD/nummod/4 daughters/4/daughter/NOUN/NNS/dobj/2')
# vera1241 0 ('qºņ vºwal e ruwa mĕn gunuruº', 'One/0/one/NUM/CD/nummod/1 day/1/day/NOUN/NN/npadvmod/3 there/2/there/PRON/EX/expl/3 was/3/be/VERB/VBD/ROOT/3 a/4/a/DET/DT/det/6 married/5/married/ADJ/JJ/amod/6 couple/6/couple/NOUN/NN/attr/3')
# vera1241 500 ('nike sºk sier lik ĕn ºnº mimiʔir nºm nike miʔir', 'Further/0/far/ADV/RB/advmod/1 more/1/more/ADV/RBR/advmod/2 find/2/find/VERB/VBP/ROOT/2 a/3/a/DET/DT/det/4 place/4/place/NOUN/NN/dobj/2 to/5/to/PART/TO/aux/6 sleep/6/sleep/VERB/VB/relcl/4 for/7/for/ADP/IN/prep/6 you/8/you/PRON/PRP/pobj/7 and/9/and/CCONJ/CC/cc/6 sleep/10/sleep/VERB/VB/conj/6 there/11/there/ADV/RB/advmod/10')
# vera1241 1000 ('bulsal rºvrºvʔe rºvrºvʔe ne kirɱº', 'Friend/0/friend/NOUN/NN/nsubj/4 almost/1/almost/ADV/RB/advmod/2 almost/2/almost/ADV/RB/advmod/4 it/3/it/PRON/PRP/nsubj/4 breaks/4/break/VERB/VBZ/ROOT/4')
# vera1241 1500 ('ne van diņ rºw ma lĕn lºlº vunuº', 'went/0/go/VERB/VBD/ROOT/0 down/1/down/ADP/RP/prt/0 into/2/into/ADP/IN/prep/0 the/3/the/DET/DT/det/4 village/4/village/NOUN/NN/pobj/2')
# warl1254 0 ('wati ka karrimi makitikirli watiyawana karnta', 'a/0/a/DET/DT/det/1 man/1/man/NOUN/NN/nsubj/3 is/2/be/AUX/VBZ/aux/3 standing/3/stand/VERB/VBG/ROOT/3 with/4/with/ADP/IN/prep/3 a/5/a/DET/DT/det/6 rifle/6/rifle/NOUN/NN/pobj/4 by/7/by/ADP/IN/prep/6 a/8/a/DET/DT/det/9 tree/9/tree/NOUN/NN/pobj/7 a/10/a/DET/DT/det/11 woman/11/woman/NOUN/NN/dobj/3 xxx/12/xxx/NOUN/NN/appos/11')
# warl1254 500 ('ngulajanga jajinyanurlu luwarnu puluku', 'then/0/then/ADV/RB/advmod/3 they/1/they/PRON/PRP/nsubj/2 father/2/father/VERB/VBP/nsubj/3 shot/3/shoot/VERB/VBD/ROOT/3 a/4/a/DET/DT/det/5 bullock/5/bullock/NOUN/NN/dobj/3')
# warl1254 1000 ('kalu warralykarrimi', "they/0/they/PRON/PRP/nsubj/2 're/1/be/AUX/VBP/aux/2 hanging/2/hang/VERB/VBG/ROOT/2")
# warl1254 1500 ('karntaju', 'the/0/the/DET/DT/det/1 woman/1/woman/NOUN/NN/ROOT/1')
# warl1254 2000 ('nyampu puluku karna kanyi ngurrakurra', "I/0/I/PRON/PRP/nsubj/2 'm/1/be/AUX/VBP/aux/2 taking/2/take/VERB/VBG/ROOT/2 this/3/this/DET/DT/det/5 bullock/4/bullock/NOUN/NN/compound/5 home/5/home/NOUN/NN/dobj/2")
