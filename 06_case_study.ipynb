# %%
import pandas as pd
from collections import Counter, defaultdict
import numpy as np
from sklearn.neural_network import MLPClassifier
import dill as pickle
import os
prepared_vectors_doc=  './generated/doreco_bert/'

# %%
def load_data(doc, min_freq=5):
    df = pd.read_excel('%s/%s_by_lemma.xlsx' % (prepared_vectors_doc, doc), na_filter=False)
    good_trm = {trm for trm, ct in Counter(df.term).items() if ct >= min_freq}
    good_mrk = {mrk for mrk, ct in Counter(df.marker).items() if ct >= min_freq}
    # print(doc, len(good_mrk), len(df), len(np.load('%s/%s_by_lemma.npy' % (prepared_vectors_doc, doc))))
    X = np.load('%s/%s_by_lemma_0.npy' % (prepared_vectors_doc, doc))[df.term.isin(good_trm) & df.marker.isin(good_mrk)]
    df = df[df.term.isin(good_trm) & df.marker.isin(good_mrk)]
    y = np.array([r.marker for i,r in df.iterrows()])
    return df, X, y

# %%
regenerate_classification_models = True
if regenerate_classification_models:
    for doc in map(lambda l : l.strip(), open('./doreco_english_doculects.txt')):
        classifier = MLPClassifier(hidden_layer_sizes=(100,),activation='relu')
        df, X, y = load_data(doc)
        h = df.term.isin({'see','watch','look'})
        if sum(h) < 30: continue
        classifier.fit(X[h],y[h])
        pickle.dump(classifier, open('%s/model_%s.p' % (prepared_vectors_doc, doc[:-4]), 'wb'))
        print(doc)
# Out:
# /home/barend/yourvenvfoldername/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# anal1239
# arap1274
# bain1259
# /home/barend/yourvenvfoldername/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# beja1238
# /home/barend/yourvenvfoldername/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# cabe1245
# cash1254
# dolg1241
# /home/barend/yourvenvfoldername/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# even1259
# goem1240
# /home/barend/yourvenvfoldername/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# goro1270
# hoch1243
# jeha1242
# jeju1234
# /home/barend/yourvenvfoldername/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# kaka1265
# /home/barend/yourvenvfoldername/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# kama1351
# /home/barend/yourvenvfoldername/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# komn1238
# ligh1234
# movi1243
# ngal1292
# /home/barend/yourvenvfoldername/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# nngg1234
# nort2641
# /home/barend/yourvenvfoldername/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# orko1234
# pnar1238
# /home/barend/yourvenvfoldername/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# port1286
# ruul1235
# savo1255
# sout2856
# sumi1235
# teop1238
# /home/barend/yourvenvfoldername/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# texi1237
# toto1304
# trin1278
# tsim1256
# urum1249
# vera1241
# warl1254

# %%
classifiers = {doc : pickle.load(open('%s/model_%s.p' % (prepared_vectors_doc, doc[:-4]), 'rb')) for  doc in map(lambda l : l.strip(), open('./doreco_english_doculects.txt'))
              if os.path.isfile('%s/model_%s.p' % (prepared_vectors_doc, doc[:-4]))}
print(len(classifiers))
builder = []
M = False
for doc in map(lambda l : l.strip(), open('./doreco_english_doculects.txt')):
    print(doc)
    df, X, y = load_data(doc)
    h = df.term.isin({'see','watch','look'})
    if sum(h) < 30: continue

    corpus = [' '.join([w.split('/')[0] for w in f.strip('\n').split(' ||| ')[1].split()])
              for f in open('./generated/doreco_bitexts/' + doc + '.spc')]
    for l,m in zip(df[h].line,df[h].marker):
        builder.append({'doculect':doc, 'lineindex' : l, 'line' : corpus[l-1] + ' | ' + corpus[l] + ' | ' + corpus[l+1] if l+1 < len(corpus) else '', 'marker' : eval(m)[1], 'seed' : eval(m)[0]})
        #print(builder[-1])
    Mdoc = np.zeros((sum(h),0))
    for c,C in classifiers.items():
        Mdoc = np.hstack([Mdoc, C.predict_proba(X[h])])
    if isinstance(M,bool): M = Mdoc
    else: M = np.vstack([M, Mdoc])
# Out:
# 37
# anal1239
# apah1238
# arap1274
# bain1259
# beja1238
# cabe1245
# cash1254
# dolg1241
# even1259
# goem1240
# goro1270
# guri1247
# hoch1243
# jeha1242
# jeju1234
# kaka1265
# kama1351
# kark1256
# komn1238
# ligh1234
# movi1243
# ngal1292
# nngg1234
# nort2641
# nort2875
# orko1234
# pnar1238
# port1286
# ruul1235
# sadu1234
# sanz1248
# savo1255
# sout2856
# sumi1235
# svan1243
# taba1259
# teop1238
# texi1237
# toto1304
# trin1278
# tsim1256
# urum1249
# vera1241
# warl1254

# %%
import seaborn as sns
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt

# %%
M.shape
# Out:
# (3001, 194)

# %%
T = TSNE(perplexity=40)
coo = T.fit_transform(M)

# %%
meta = pd.DataFrame(builder)
top_seed = Counter(meta.seed)
sns.scatterplot(x=coo[meta.seed.isin({'see','look','watch'}),0], y=coo[meta.seed.isin({'see','look','watch'}),1], hue=meta[meta.seed.isin({'see','look','watch'})].seed)
#plt.tight_layout()
plt.savefig('/home/barend/Dropbox/Apps/Overleaf/Inferred Lexification (SigTyp 2025)/latex/figures/seed.png')

# %%
for doc in classifiers: 
    if doc[:4] in {'cash', 'dolg', 'sumi', 'teop','urum'}:
        print(doc)
        sns.scatterplot(x=coo[meta.doculect==doc,0], y=coo[meta.doculect==doc,1], hue=meta[meta.doculect==doc].marker, s=60)
        #sns.kdeplot(x=coo[meta.doculect==doc,0], y=coo[meta.doculect==doc,1], hue=meta[meta.doculect==doc].marker, levels=1, thresh=0.05)
        plt.xlim(coo[:,0].min(), coo[:,0].max())
        plt.ylim(coo[:,1].min(), coo[:,1].max())
        plt.savefig('/home/barend/Dropbox/Apps/Overleaf/Inferred Lexification (SigTyp 2025)/latex/figures/%s.png' % doc)
        plt.tight_layout()
        plt.show()
# Out:
# cash1254
# dolg1241
# sumi1235
# teop1238
# urum1249

# %%
meta[meta.marker == '^bena'].line.tolist()
# Out:
# ['did not move it was spinning in the same place he was continuously honking he did txaan txaan I saw passing by | In the afternoon he went to look for uricuri at the bank of the lake | He looks for mushrooms there are no mushrooms',
#  'It was the one that used to copulate with the anaconda There had come the tapir of the woods | He started to look for his family | Mo he said',
#  'there were so many we had never seen so many kinds of animals he showed me | He had gone to look around for jenipapo There the jenipapo was lying | You made your wife and your children become poor ones he said',
#  "I ca n't speak Spanish | Ah quick my family is looking for me he said | You didn´t do that what is it they asked",
#  'Ah you are like that That´s good | to keep me in it the same My family is looking for me he said | I killed something let´s eat he said',
#  'Over there I killed a leptotila he said | The wife his children and his parents - in - law were looking for him | Here not far they killed a snake',
#  'I think that he went out of the hiding - place came and had sex with her | Ah my family is looking for me he said | when they started to arrive',
#  'Stopped having sex with her | My children are looking for me he said | Ah let´s see They will die',
#  'Go she said | Don´t go your family is looking for you they said he didn´t listen at all | She had fallen with closed legs',
#  'he said he told me I entered the school | They are not looking for me any more they have already looked for me he said and went away | She covered her wrapped her well they didn´t manage to pull out her arrow',
#  'She took him to the water they went she kept pulling him kept pulling him | There that one the arrow fell on the daughter and the son who were right then looking for him and standing there | we taught him our language and he gave us food',
#  'Is it possible that you´re not afraid she asked | For many days I have been looking for you together with grandmother and my grandfather and my mother | They had lived at the same place and wanted to return again he made us come to the Curanja river',
#  'He came she made him lie down in a hammock | Now we have looked for you for several days now we have looked for you for several days | We lived on',
#  'Where is he she wanted to know | Then you left me you made me look for you | Right now I don´t want you any more as a husband',
#  "Her father didn´t have space to move | Now I´ve been looking for you for a long time how is it that you are such a useless man | I kept waiting I kept waiting at one o'clock there was dust and a car was honking",
#  'Various types of fish were looking at him he didn´t say anything was lying down | Where is he there his human family was looking for him Where is he | he was pacing back and forth',
#  'He said to them to his family Ah get ayahuasca for me | he was looking for us he found us we got in the car we went | There he made them afraid you see']

# %%
meta[(meta.seed == 'see') & (meta.marker == '^bah')].line.tolist()
# Out:
# ['But people who have lived in Tbilisi for many years I ca n’t differ whether they are Georgians or Urum | They see how they dress and they dress also in such a way | Georgians do n’t love working they love food and stuff',
#  'Our people came to Tbilisi from Turkey | If you do n’t believe count and see | My father could sing',
#  'Where I am from | If you do n’t believe me count and see | If you do n’t believe count and see',
#  'If you do n’t believe me count and see | If you do n’t believe count and see | If you do n’t believe count and you will see',
#  'If you do n’t believe count and see | If you do n’t believe count and you will see | If you do n’t believe count and see',
#  'If you do n’t believe count and you will see | If you do n’t believe count and see | I said I love you',
#  'Many of our people speak Armenian too | But you ca n’t see a big difference | Urum women are at home all day',
#  'I wonder how these people lived here that ’s why I guess they moved to Greece and Germany | But they visit their houses in summer to see in which conditions are they and also to build them | I do n’t know about it now',
#  'Well we had some conflict at home also I remember when my grandfather told to my grandmother : “ woman why do we have these four walls They are for the reason that whatever is spoken here should not go outside . ” | I want to go for studies I will see where to go possibly to the city | One of my brothers is here and another is in Greece also my parents are here too']
